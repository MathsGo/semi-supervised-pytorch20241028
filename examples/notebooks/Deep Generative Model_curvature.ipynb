# %%
# Imports
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import random_split
import torchvision.transforms as transforms
import torch.nn.functional as F

cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.io
import sys
sys.path.append("../../semi-supervised")

# %% [markdown]
# # Deep Generative Model
#
# In this notebook we show how you can use the deep "generative model for semi-supervised learning" as presented in [[Kingma 2014]](https://arxiv.org/abs/1406.5298). The paper posits three different models, though we are just interested in two of these: the M2 model and the M1+M2 model.
#
# The M1 model is just a variational autoencoder, so we refer to the previous notebook for more information on this. The M2 model however is an extension to the VAE to include label information for a semi-supervised objective. The structure is shown below (left: inference model, right: generative model).
#
# <img src="../images/dgm.png" width="400px"/>
#
# The point of the generative model is to seperate the partially observed label information $y$ from the latent variable $z$ in order to learn a representation that seperates these two variables. We can use this model for semi-supervised learning as the inference model must also infer the label from the data $x$ along with the latent variable $z$.

# %%
from models import DeepGenerativeModel, StackedDeepGenerativeModel

y_dim = 1
z_dim = 32
h_dim = [256, 128]

model = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
model
# Out:
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\vae.py:114: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\dgm.py:67: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=785, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
#   (classifier): Classifier(
#     (dense): Linear(in_features=784, out_features=256, bias=True)
#     (logits): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (regressor): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=1, bias=True)
#       (log_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
print(model.encoder.hidden[0])
print(model.decoder.hidden[0])
# Out:
# Linear(in_features=785, out_features=256, bias=True)
# Linear(in_features=33, out_features=128, bias=True)

# %% [markdown]
# Notice how theres now a classifier associated with model. This classifier will just be a simple model that takes the size of the first layer encoder network. We also have a larger input space on both the encoder and decoder to make room for label information, in this case 10 labels.

# %% [markdown]
# ## Training
#
# Recall the ELBO from the VAE formulation, we want to construct a similar ELBO when we include labelled data $y$. In the case that we have labels, the ELBO has a simple formulation that is similar to the one for the VAE. The difference here is that we must also have a prior over labels $p(y)$, which we choose to be uniform over the different classes.
#
# \begin{align}
# \log p(x, y) &= \log \int q(z|x, y) \frac{p(x, y, z)}{q(z|xy)} \ dz \geq \int q(z|x, y) \log \frac{p(x, y, z)}{q(z|xy)} \ dz\\
# &= \int q(z|x, y) [ \log p(x|z,y) + \log p(y) ] \ dz + \int q(z|x, y) \log \frac{p(z)}{q(z|xy)} \ dz\\
# &= \mathbb{E}_{q(z|x, y)} [ \log p(x|z,y) + \log p(y) ] - KL(p(z)||q(z|xy)) = - \mathcal{L}(x, y)
# \end{align}
#
# In the case when the labels are not observed, we can instead integrate over all of the labels to achieve the same effect.
#
# \begin{align}
# \log p(x) &= \log \sum_{y} \int q(z,y|x) \frac{p(x, y, z)}{q(z,y|x)} \ dz \geq \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz\\
# &= \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz + \sum_{y} q(y|x) \log q(y|x) \int q(z|x, y) \ dz\\
# &= \sum_{y} q(y|x) (- \mathcal{L}(x,y)) + \mathcal{H}(q(y|x)) = - \mathcal{U}(x)
# \end{align}
#
# Notice how in both cases we need to compute the labelled bound, but in the unlabelled case we need to do it $n$ times where $n$ is the number of classes. In this model, we do not learn directly from the labelled class, as there is no cross entropy term between $y$ and our model output $q(y|x)$. We therefore add an auxiliary loss to arrive at the final loss objective.
#
# $$\mathcal{J}^{\alpha} = \sum_{(x_l, y_l)}\mathcal{L}(x_l, y_l) + \alpha \cdot \mathbb{E}_{x_l, y_l}[- \log q(y_l|x_l)] + \sum_{(x_u)}\mathcal{U}(x_u)$$
#
# Where $l, u$ denotes labelled and unlabelled data respectively and $\alpha$ is a hyperparameter that denotes the reliance of labelled data.

# %%
# from datautils import get_mnist

# # Only use 10 labelled examples per class
# # The rest of the data is unlabelled.
# labelled, unlabelled, validation = get_mnist(location="./", batch_size=64, labels_per_class=10)
# alpha = 0.1 * len(unlabelled) / len(labelled)


# def binary_cross_entropy(r, x):
#     return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999))

# %% [markdown]
# # Load Data

# %%
data = scipy.io.loadmat('./data/heston_vol_images_train_30000.mat')
impliedVolsurfaces = torch.tensor(data['impliedVolsurfaces_collection']).float()

max_val = torch.max(impliedVolsurfaces)
min_val = torch.min(impliedVolsurfaces)

impliedVolsurfaces_normalized = (impliedVolsurfaces - min_val) / (max_val - min_val)

impliedVolsurfaces_normalized_flatten = impliedVolsurfaces_normalized.reshape(30000, 784)

lhs_matrix = data["lhs_matrix"]  # 形状: [30000, 6]

# 获取公式中的变量
rho = lhs_matrix[:, 0]       # 第 1 列，rho
v0 = lhs_matrix[:, 2]        # 第 3 列，v0
gamma = lhs_matrix[:, 3]     # 第 4 列，gamma

# 计算公式
cur_0 = torch.from_numpy((gamma**2) / (24 * v0**(3/2)) * (2 - 5 * rho**2)).type(torch.float32)

# slope = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=1, axis=2)) * 1000
# # K_index_s = slope.shape[2] // 2
# # slope = torch.from_numpy(slope[:, :, K_index_s, :])
# slope_ave = torch.mean(slope, dim=[2, 3]).squeeze(1)
# print("slope:", slope_ave.shape, slope_ave.min(), slope_ave.max())

# curvature = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=2, axis=2)) * 1000
# # K_index_c = curvature.shape[2] // 2
# # curvature = torch.from_numpy(curvature[:, :, K_index_c, :])
# # curvature_ave = torch.max(curvature, dim=[2, 3]).squeeze(1)
# values, indices = curvature.reshape(30000, -1).sort()
# curvature_l3 = values[:, -3]
# # print("curvature:", curvature_ave.shape, curvature.min(), curvature.max())
# print("curvature:", curvature_l3.shape, curvature_l3.min(), curvature_l3.max())

tar = cur_0

# # tar = torch.stack([level, slope_ave, curvature_l3], dim=1)
# # print(tar.shape)

ivs = TensorDataset(impliedVolsurfaces_normalized_flatten, tar)

torch.manual_seed(0)

total_size = len(ivs)
train_size = int(total_size * 0.7)
labelled_size = int(train_size * 1)
# labelled_size = int(train_size * 0.1)
# labelled_size = int(0)
# unlabelled_size = train_size - labelled_size
validation_size = total_size - train_size
alpha = 0.1 * train_size


# labelled_dataset, unlabelled_dataset, validation_dataset = random_split(ivs, [labelled_size, unlabelled_size, validation_size])
labelled_dataset, validation_dataset = random_split(ivs, [labelled_size,  validation_size])

BATCH_SIZE = 64
EPOCH = 5001

labelled = DataLoader(labelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
# unlabelled = DataLoader(unlabelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# import torch
# import numpy as np

# # 模拟生成 z 的数据（3000 张 28x28 的 torch tensor surface）
# z = impliedVolsurfaces_normalized.squeeze(1)

# # K 和 T 的 linspace
# K = np.linspace(0.7, 1.3, 28)
# T = np.linspace(0.1, 0.6, 28)
# dK = K[1] - K[0]  # K 的步长

# # 定义计算曲率的函数
# def calculate_curvature(surface):
#     """
#     计算一张 surface 沿 K 方向的平均曲率
#     """
#     # 转为 numpy 数组以方便处理
#     surface_np = surface.numpy()

#     # 沿着 K 方向计算二阶导数 (曲率)
#     # 采用有限差分： f''(K) ≈ (f(K+1) - 2*f(K) + f(K-1)) / dK^2
#     curvature = (surface_np[2:, :] - 2 * surface_np[1:-1, :] + surface_np[:-2, :]) / dK**2

#     # 返回整张 surface 的平均曲率
#     return curvature.mean()

# # 对所有 surfaces 计算平均曲率
# average_curvatures = torch.tensor([calculate_curvature(surface) for surface in z])

# # 给出示例
# example_surface_index = 0
# example_surface = z[example_surface_index]
# example_average_curvature = calculate_curvature(example_surface)

# print(f"Example Surface Index: {example_surface_index}")
# print(f"Example Average Curvature: {example_average_curvature}")
# print(f"All Average Curvatures Shape: {average_curvatures.shape}")
# average_curvatures.min(), average_curvatures.max()

# %%
# # level min max
# from mpl_toolkits.mplot3d import Axes3D

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[level.argmin()].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[level.argmax()].view(28, 28), cmap='viridis')

# %%
# # slope min max
# from mpl_toolkits.mplot3d import Axes3D

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmin()].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmax()].view(28, 28), cmap='viridis')

# %%
# # curvature min max
# from mpl_toolkits.mplot3d import Axes3D

# sorted, indices = curvature_l3.sort()
# print(sorted)
# print(indices)

# i = 1

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[-i]].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[i]].view(28, 28), cmap='viridis')

# %%
from itertools import cycle
from inference import SVI, ImportanceWeightedSampler

# You can use importance weighted samples [Burda, 2015] to get a better estimate
# on the log-likelihood.
sampler = ImportanceWeightedSampler(mc=1, iw=1)

if cuda: model = model.cuda()
elbo = SVI(model, likelihood=F.mse_loss, sampler=sampler)

# %% [markdown]
# The library is conventially packed with the `SVI` method that does all of the work of calculating the lower bound for both labelled and unlabelled data depending on whether the label is given. It also manages to perform the enumeration of all the labels.
#
# Remember that the labels have to be in a *one-hot encoded* format in order to work with SVI.

# %%
from torch.autograd import Variable

J_collect = []
L_collect = []
MSE_collect = []

for epoch in range(1, EPOCH):
    model.train()
    total_loss, L_sum, MSE_sum = (0, 0, 0)
    for x, y in labelled:
        # Wrap in variables
        # x, y, u = Variable(x), Variable(y), Variable(u)
        # y = y.unsqueeze(1)
        x, y = Variable(x), Variable(y)
        # print(x, y)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            # u = u.cuda(device=0)

        L = -elbo(x, y)
        # U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        pred_y, y_mu, y_logvar = model.regress(x)
        # print(pred_y.shape)
        pred_y = pred_y.squeeze(1)
        # print(pred_y.shape)
        # print(pred_y.sum())
        
        # Regular cross entropy
        # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
        # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
        regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()

        J_alpha = L + alpha * regression_loss

        J_alpha.backward()
        # L.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.item()
        # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
    if epoch % 100 == 0:
        print("Epoch: {}, ELBO now is {}, regression loss is {}".format(epoch, L, regression_loss))
        print("pred_y:", pred_y.t())
        print("y_mu:", y_mu.t())
        print("y_std:", y_logvar.mul(0.5).exp_().t())
        print('real y:', y.view(-1))
        
    if epoch % 1 == 0:
        model.eval()
        # m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        # print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, L_sum, MSE_sum = (0, 0, 0)
        for x, y in validation:
            # y = y.unsqueeze(1)
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            # U = -elbo(x)

            # logits = model.classify(x)
            pred_y, y_mu, y_logvar = model.regress(x)

            # classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()
            # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
            # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
            # print(pred_y.shape)
            pred_y = pred_y.squeeze(1)
            # print(pred_y.shape)
            regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()
            J_alpha = L + alpha * regression_loss



            total_loss += J_alpha.item()
            L_sum += L.item()
            MSE_sum += regression_loss.item()

            # print(J_alpha.item())
            # print(L.item())
            # print(alpha * regression_loss.item())

            # _, pred_idx = torch.max(logits, 1)
            # _, lab_idx = torch.max(y, 1)
            # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

    
        m = len(validation)
        print("[Validation]\t J_a: {:.2f}".format(total_loss / m))
        print("[Validation]\t L: {:.4f}".format(L_sum / m)) # !didn't sum over L, need to be changed
        print("[Validation]\t alpha * MSE: {:.2f}".format(alpha * MSE_sum / m)) # !didn't sum over regression_loss, need to be changed

        J_collect.append(total_loss / m)
        L_collect.append(L_sum / m)
        MSE_collect.append(MSE_sum / m)
        # print("[Validation]\t L: {:.2f}".format(total_loss / m))
# Out:
# Epoch: 1
# [Validation]	 J_a: 6602.72
# [Validation]	 L: -63.4312
# [Validation]	 alpha * MSE: 6666.15
# Epoch: 2
# [Validation]	 J_a: 1899.54
# [Validation]	 L: -63.4317
# [Validation]	 alpha * MSE: 1962.97
# Epoch: 3
# [Validation]	 J_a: 2870.41
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 2933.84
# Epoch: 4
# [Validation]	 J_a: 1011.07
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 1074.50
# Epoch: 5
# [Validation]	 J_a: 957.22
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 1020.65
# Epoch: 6
# [Validation]	 J_a: 589.29
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 652.72
# Epoch: 7
# [Validation]	 J_a: 4452.26
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 4515.69
# Epoch: 8
# [Validation]	 J_a: 431.73
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 495.16
# Epoch: 9
# [Validation]	 J_a: 353.97
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 417.41
# Epoch: 10
# [Validation]	 J_a: 730.16
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 793.59
# Epoch: 11
# [Validation]	 J_a: 218.68
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 282.11
# Epoch: 12
# [Validation]	 J_a: 2063.42
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 2126.85
# Epoch: 13
# [Validation]	 J_a: 196.12
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 259.55
# Epoch: 14
# [Validation]	 J_a: 1917.20
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 1980.63
# Epoch: 15
# [Validation]	 J_a: 344.34
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 407.77
# Epoch: 16
# [Validation]	 J_a: 158.63
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 222.07
# Epoch: 17
# [Validation]	 J_a: 222.33
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 285.76
# Epoch: 18
# [Validation]	 J_a: 2226.79
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 2290.22
# Epoch: 19
# [Validation]	 J_a: 279.85
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 343.28
# Epoch: 20
# [Validation]	 J_a: 119.74
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 183.18
# Epoch: 21
# [Validation]	 J_a: 1393.59
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 1457.02
# Epoch: 22
# [Validation]	 J_a: 89.70
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 153.13
# Epoch: 23
# [Validation]	 J_a: 1672.92
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 1736.36
# Epoch: 24
# [Validation]	 J_a: 236.61
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 300.04
# Epoch: 25
# [Validation]	 J_a: 109.54
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 172.97
# Epoch: 26
# [Validation]	 J_a: 298.74
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 362.17
# Epoch: 27
# [Validation]	 J_a: 54.74
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 118.17
# Epoch: 28
# [Validation]	 J_a: 389.59
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 453.02
# Epoch: 29
# [Validation]	 J_a: 192.35
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 255.78
# Epoch: 30
# [Validation]	 J_a: 177.52
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 240.96
# Epoch: 31
# [Validation]	 J_a: 450.63
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 514.06
# Epoch: 32
# [Validation]	 J_a: 193.83
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 257.26
# Epoch: 33
# [Validation]	 J_a: 1199.80
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 1263.23
# Epoch: 34
# [Validation]	 J_a: 650.42
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 713.85
# Epoch: 35
# [Validation]	 J_a: 122.63
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 186.06
# Epoch: 36
# [Validation]	 J_a: 375.10
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 438.54
# Epoch: 37
# [Validation]	 J_a: 493.00
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 556.43
# Epoch: 38
# [Validation]	 J_a: 119.60
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 183.03
# Epoch: 39
# [Validation]	 J_a: 367.49
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 430.92
# Epoch: 40
# [Validation]	 J_a: 117.43
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 180.86
# Epoch: 41
# [Validation]	 J_a: 181.70
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 245.13
# Epoch: 42
# [Validation]	 J_a: 37.07
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 100.51
# Epoch: 43
# [Validation]	 J_a: 41.25
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 104.68
# Epoch: 44
# [Validation]	 J_a: 445.08
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 508.52
# Epoch: 45
# [Validation]	 J_a: 2316.60
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 2380.04
# Epoch: 46
# [Validation]	 J_a: 32.61
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 96.04
# Epoch: 47
# [Validation]	 J_a: 131.24
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 194.68
# Epoch: 48
# [Validation]	 J_a: 24.00
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 87.43
# Epoch: 49
# [Validation]	 J_a: 464.64
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 528.07
# Epoch: 50
# [Validation]	 J_a: 169.51
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 232.95
# Epoch: 51
# [Validation]	 J_a: 40.14
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 103.57
# Epoch: 52
# [Validation]	 J_a: 377.47
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 440.90
# Epoch: 53
# [Validation]	 J_a: 103.25
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 166.69
# Epoch: 54
# [Validation]	 J_a: 179.31
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 242.74
# Epoch: 55
# [Validation]	 J_a: 54.88
# [Validation]	 L: -63.4320
# [Validation]	 alpha * MSE: 118.31
# Epoch: 56
# [Validation]	 J_a: 15.16
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 78.59
# Epoch: 57
# [Validation]	 J_a: 33.41
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 96.84
# Epoch: 58
# [Validation]	 J_a: 208.54
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 271.97
# Epoch: 59
# [Validation]	 J_a: 36.51
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 99.94
# Epoch: 60
# [Validation]	 J_a: 19.92
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 83.35
# Epoch: 61
# [Validation]	 J_a: 85.38
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 148.81
# Epoch: 62
# [Validation]	 J_a: 420.21
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 483.64
# Epoch: 63
# [Validation]	 J_a: 464.76
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 528.20
# Epoch: 64
# [Validation]	 J_a: 80.58
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 144.01
# Epoch: 65
# [Validation]	 J_a: 88.49
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 151.93
# Epoch: 66
# [Validation]	 J_a: 16.52
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 79.96
# Epoch: 67
# [Validation]	 J_a: 721.10
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 784.53
# Epoch: 68
# [Validation]	 J_a: 334.39
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 397.82
# Epoch: 69
# [Validation]	 J_a: 158.99
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 222.42
# Epoch: 70
# [Validation]	 J_a: 159.16
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 222.59
# Epoch: 71
# [Validation]	 J_a: 88.14
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 151.57
# Epoch: 72
# [Validation]	 J_a: 140.10
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 203.53
# Epoch: 73
# [Validation]	 J_a: 527.28
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 590.72
# Epoch: 74
# [Validation]	 J_a: 227.27
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 290.70
# Epoch: 75
# [Validation]	 J_a: 126.78
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 190.21
# Epoch: 76
# [Validation]	 J_a: 20.88
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 84.31
# Epoch: 77
# [Validation]	 J_a: 1079.88
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 1143.31
# Epoch: 78
# [Validation]	 J_a: 39.75
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 103.18
# Epoch: 79
# [Validation]	 J_a: 23.41
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 86.85
# Epoch: 80
# [Validation]	 J_a: 496.94
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 560.38
# Epoch: 81
# [Validation]	 J_a: 292.16
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 355.59
# Epoch: 82
# [Validation]	 J_a: 58.45
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 121.89
# Epoch: 83
# [Validation]	 J_a: 620.99
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 684.42
# Epoch: 84
# [Validation]	 J_a: 20.23
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 83.67
# Epoch: 85
# [Validation]	 J_a: 175.08
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 238.51
# Epoch: 86
# [Validation]	 J_a: 3.65
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 67.08
# Epoch: 87
# [Validation]	 J_a: 444.61
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 508.05
# Epoch: 88
# [Validation]	 J_a: 149.10
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 212.54
# Epoch: 89
# [Validation]	 J_a: 69.03
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 132.46
# Epoch: 90
# [Validation]	 J_a: 395.99
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 459.42
# Epoch: 91
# [Validation]	 J_a: 67.57
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 131.00
# Epoch: 92
# [Validation]	 J_a: 4.45
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 67.89
# Epoch: 93
# [Validation]	 J_a: 331.16
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 394.59
# Epoch: 94
# [Validation]	 J_a: 35.44
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 98.87
# Epoch: 95
# [Validation]	 J_a: 11.88
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 75.31
# Epoch: 96
# [Validation]	 J_a: 190.41
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 253.84
# Epoch: 97
# [Validation]	 J_a: 25.81
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 89.24
# Epoch: 98
# [Validation]	 J_a: 407.17
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 470.60
# Epoch: 99
# [Validation]	 J_a: 11.35
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 74.79
# Epoch: 100, ELBO now is -7.4574408531188965, regression loss is 0.010677957907319069
# pred_y: tensor([ 0.3635,  0.0191,  0.1621, -0.2200, -0.0298, -0.0983, -0.0954, -0.1375],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.3635,  0.0189,  0.1622, -0.2200, -0.0301, -0.0981, -0.0954, -0.1373]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[5.4638e-05, 1.4082e-04, 2.1657e-04, 4.0078e-05, 9.8849e-04, 2.6595e-04,
#          3.1849e-05, 2.7767e-04]], grad_fn=<TBackward0>)
# real y: tensor([ 0.3930,  0.0691,  0.1873, -0.1702,  0.0110, -0.0862, -0.0620, -0.1020])
# Epoch: 100
# [Validation]	 J_a: 928.18
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 991.62
# Epoch: 101
# [Validation]	 J_a: 108.31
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 171.74
# Epoch: 102
# [Validation]	 J_a: 103.52
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 166.96
# Epoch: 103
# [Validation]	 J_a: 75.04
# [Validation]	 L: -63.4321
# [Validation]	 alpha * MSE: 138.47
# Epoch: 104
# [Validation]	 J_a: 253.53
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 316.96
# Epoch: 105
# [Validation]	 J_a: 9.39
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 72.83
# Epoch: 106
# [Validation]	 J_a: 185.35
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 248.79
# Epoch: 107
# [Validation]	 J_a: 46.20
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 109.63
# Epoch: 108
# [Validation]	 J_a: 170.70
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE:
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 393.30
# Epoch: 200, ELBO now is -8.194914817810059, regression loss is 0.0014438977232202888
# pred_y: tensor([-0.1919,  0.0749, -0.6775,  0.0153, -0.6980,  0.2755, -0.6726,  0.4508],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[-0.1918,  0.0749, -0.6775,  0.0144, -0.6980,  0.2756, -0.6726,  0.4509]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[4.0392e-05, 1.8774e-05, 1.7596e-06, 8.4430e-04, 2.2029e-05, 4.6789e-05,
#          5.0335e-06, 4.7185e-05]], grad_fn=<TBackward0>)
# real y: tensor([-0.1896,  0.0733, -0.6702,  0.0156, -0.6826,  0.2809, -0.6752,  0.4174])
# Epoch: 200
# [Validation]	 J_a: 1.25
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 64.68
# Epoch: 201
# [Validation]	 J_a: 21.81
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 85.24
# Epoch: 202
# [Validation]	 J_a: 85.85
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 149.28
# Epoch: 203
# [Validation]	 J_a: -18.85
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 44.59
# Epoch: 204
# [Validation]	 J_a: 390.85
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 454.29
# Epoch: 205
# [Validation]	 J_a: 6.55
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 69.99
# Epoch: 206
# [Validation]	 J_a: 1252.56
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 1315.99
# Epoch: 207
# [Validation]	 J_a: 80.12
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 143.55
# Epoch: 208
# [Validation]	 J_a: 206.80
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 270.23
# Epoch: 209
# [Validation]	 J_a: 268.64
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 332.07
# Epoch: 210
# [Validation]	 J_a: 122.69
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 186.12
# Epoch: 211
# [Validation]	 J_a: 58.61
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 122.04
# Epoch: 212
# [Validation]	 J_a: 51.01
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 114.44
# Epoch: 213
# [Validation]	 J_a: -29.54
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 33.89
# Epoch: 214
# [Validation]	 J_a: 147.91
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 211.34
# Epoch: 215
# [Validation]	 J_a: 104.24
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 167.68
# Epoch: 216
# [Validation]	 J_a: 75.49
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 138.93
# Epoch: 217
# [Validation]	 J_a: 197.63
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 261.06
# Epoch: 218
# [Validation]	 J_a: -21.28
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 42.15
# Epoch: 219
# [Validation]	 J_a: 85.34
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 148.78
# Epoch: 220
# [Validation]	 J_a: 7.22
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 70.65
# Epoch: 221
# [Validation]	 J_a: 29.16
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 92.59
# Epoch: 222
# [Validation]	 J_a: -9.43
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 54.00
# Epoch: 223
# [Validation]	 J_a: -9.06
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 54.37
# Epoch: 224
# [Validation]	 J_a: -23.29
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 40.14
# Epoch: 225
# [Validation]	 J_a: 18.76
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 82.19
# Epoch: 226
# [Validation]	 J_a: 77.93
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 141.37
# Epoch: 227
# [Validation]	 J_a: 161.15
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 224.59
# Epoch: 228
# [Validation]	 J_a: 7.21
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 70.64
# Epoch: 229
# [Validation]	 J_a: 148.03
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 211.46
# Epoch: 230
# [Validation]	 J_a: 41.79
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 105.22
# Epoch: 231
# [Validation]	 J_a: 651.60
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 715.03
# Epoch: 232
# [Validation]	 J_a: 90.75
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 154.18
# Epoch: 233
# [Validation]	 J_a: -3.83
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 59.60
# Epoch: 234
# [Validation]	 J_a: 11.91
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 75.34
# Epoch: 235
# [Validation]	 J_a: 21.56
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 85.00
# Epoch: 236
# [Validation]	 J_a: -1.39
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 62.04
# Epoch: 237
# [Validation]	 J_a: 3.75
# [Validation]	 L: -63.4321
# [Validation]	 alpha * MSE: 67.18
# Epoch: 238
# [Validation]	 J_a: -5.08
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE:
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 56.97
# Epoch: 286
# [Validation]	 J_a: -24.68
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 38.75
# Epoch: 287
# [Validation]	 J_a: 1029.02
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 1092.45
# Epoch: 288
# [Validation]	 J_a: 71.33
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 134.76
# Epoch: 289
# [Validation]	 J_a: -7.53
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 55.90
# Epoch: 290
# [Validation]	 J_a: 4.16
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 67.60
# Epoch: 291
# [Validation]	 J_a: 67.66
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 131.09
# Epoch: 292
# [Validation]	 J_a: 8.62
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 72.05
# Epoch: 293
# [Validation]	 J_a: 119.87
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 183.30
# Epoch: 294
# [Validation]	 J_a: -25.20
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 38.24
# Epoch: 295
# [Validation]	 J_a: -15.81
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 47.63
# Epoch: 296
# [Validation]	 J_a: 81.72
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 145.16
# Epoch: 297
# [Validation]	 J_a: 12.09
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 75.53
# Epoch: 298
# [Validation]	 J_a: 27.03
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 90.46
# Epoch: 299
# [Validation]	 J_a: 47.42
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 110.85
# Epoch: 300, ELBO now is -7.92329216003418, regression loss is 0.007314363494515419
# pred_y: tensor([-0.6738,  0.4173,  0.3820, -0.2644, -0.0114,  0.0779,  0.4583,  0.2344],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[-0.6738,  0.4174,  0.3820, -0.2644, -0.0113,  0.0779,  0.4583,  0.2344]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[3.7820e-07, 7.3934e-06, 6.1284e-06, 2.0867e-05, 1.0781e-05, 1.5591e-05,
#          2.1171e-06, 7.7742e-06]], grad_fn=<TBackward0>)
# real y: tensor([-0.6483,  0.4345,  0.4262, -0.2352,  0.0245,  0.1082,  0.4804,  0.2639])
# Epoch: 300
# [Validation]	 J_a: 125.92
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 189.35
# Epoch: 301
# [Validation]	 J_a: 20.56
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 83.99
# Epoch: 302
# [Validation]	 J_a: -17.25
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 46.18
# Epoch: 303
# [Validation]	 J_a: 102.03
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 165.46
# Epoch: 304
# [Validation]	 J_a: -26.18
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 37.25
# Epoch: 305
# [Validation]	 J_a: -34.69
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 28.74
# Epoch: 306
# [Validation]	 J_a: 77.41
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 140.84
# Epoch: 307
# [Validation]	 J_a: -35.60
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 27.83
# Epoch: 308
# [Validation]	 J_a: 9.67
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 73.11
# Epoch: 309
# [Validation]	 J_a: 14.02
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 77.45
# Epoch: 310
# [Validation]	 J_a: 22.82
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 86.26
# Epoch: 311
# [Validation]	 J_a: 135.87
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 199.30
# Epoch: 312
# [Validation]	 J_a: 205.35
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 268.78
# Epoch: 313
# [Validation]	 J_a: 31.06
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 94.50
# Epoch: 314
# [Validation]	 J_a: -27.47
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 35.96
# Epoch: 315
# [Validation]	 J_a: 244.26
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 307.69
# Epoch: 316
# [Validation]	 J_a: -35.49
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 27.94
# Epoch: 317
# [Validation]	 J_a: -32.34
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 31.09
# Epoch: 318
# [Validation]	 J_a: -0.09
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 63.35
# Epoch: 319
# [Validation]	 J_a: 31.62
# [Validation]	 L: -63.4339
# [Validation]	 alpha * MSE: 95.06
# Epoch: 320
# [Validation]	 J_a: -15.29
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE:
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 33.67
# Epoch: 364
# [Validation]	 J_a: 363.48
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 426.91
# Epoch: 365
# [Validation]	 J_a: -39.35
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 24.08
# Epoch: 366
# [Validation]	 J_a: -32.34
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 31.09
# Epoch: 367
# [Validation]	 J_a: 500.28
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 563.71
# Epoch: 368
# [Validation]	 J_a: 147.06
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 210.49
# Epoch: 369
# [Validation]	 J_a: 72.52
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 135.95
# Epoch: 370
# [Validation]	 J_a: 1405.48
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 1468.91
# Epoch: 371
# [Validation]	 J_a: -35.28
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 28.16
# Epoch: 372
# [Validation]	 J_a: -13.94
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 49.49
# Epoch: 373
# [Validation]	 J_a: 100.71
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 164.15
# Epoch: 374
# [Validation]	 J_a: 271.58
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 335.02
# Epoch: 375
# [Validation]	 J_a: 14.55
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 77.98
# Epoch: 376
# [Validation]	 J_a: -35.82
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 27.61
# Epoch: 377
# [Validation]	 J_a: -37.10
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 26.33
# Epoch: 378
# [Validation]	 J_a: 10.38
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 73.81
# Epoch: 379
# [Validation]	 J_a: -34.48
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 28.95
# Epoch: 380
# [Validation]	 J_a: 141.90
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 205.33
# Epoch: 381
# [Validation]	 J_a: 229.50
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 292.93
# Epoch: 382
# [Validation]	 J_a: 21.59
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 85.02
# Epoch: 383
# [Validation]	 J_a: 123.05
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 186.49
# Epoch: 384
# [Validation]	 J_a: 165.21
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 228.64
# Epoch: 385
# [Validation]	 J_a: -37.69
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 25.75
# Epoch: 386
# [Validation]	 J_a: 179.94
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 243.37
# Epoch: 387
# [Validation]	 J_a: 147.65
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 211.09
# Epoch: 388
# [Validation]	 J_a: 21.81
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 85.24
# Epoch: 389
# [Validation]	 J_a: -29.44
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 33.99
# Epoch: 390
# [Validation]	 J_a: -13.01
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 50.42
# Epoch: 391
# [Validation]	 J_a: -38.53
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 24.91
# Epoch: 392
# [Validation]	 J_a: 322.53
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 385.96
# Epoch: 393
# [Validation]	 J_a: 26.42
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 89.85
# Epoch: 394
# [Validation]	 J_a: -9.30
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 54.14
# Epoch: 395
# [Validation]	 J_a: -2.03
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 61.40
# Epoch: 396
# [Validation]	 J_a: -24.67
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 38.76
# Epoch: 397
# [Validation]	 J_a: 69.37
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 132.80
# Epoch: 398
# [Validation]	 J_a: 9.37
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 72.81
# Epoch: 399
# [Validation]	 J_a: 94.44
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 157.88
# Epoch: 400, ELBO now is -7.6724348068237305, regression loss is 0.0010253010550513864
# pred_y: tensor([ 0.0537, -0.0667, -0.2875, -0.0398, -0.2778,  0.0302,  0.1968,  0.6914],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.0537, -0.0667, -0.2875, -0.0398, -0.2778,  0.0303,  0.1968,  0.6914]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.0631e-05, 6.2864e-05, 1.4523e-05, 5.3681e-07, 3.3691e-05, 3.0802e-05,
#          3.5953e-06, 9.0774e-06]], grad_fn=<TBackward0>)
# real y: tensor([ 0.0456, -0.0738, -0.2769, -0.0262, -0.2850,  0.0222,  0.1915,  0.7130])
# Epoch: 400
# [Validation]	 J_a: 323.64
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 387.07
# Epoch: 401
# [Validation]	 J_a: 1.81
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 65.25
# Epoch: 402
# [Validation]	 J_a: -35.96
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 27.47
# Epoch: 403
# [Validation]	 J_a: -19.95
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 43.49
# Epoch: 404
# [Validation]	 J_a: 11.80
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 75.24
# Epoch: 405
# [Validation]	 J_a: 107.41
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 170.84
# Epoch: 406
# [Validation]	 J_a: 109.90
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 173.34
# Epoch: 407
# [Validation]	 J_a: 54.79
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 118.22
# Epoch: 408
# [Validation]	 J_a: -36.38
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 27.05
# Epoch: 409
# [Validation]	 J_a: -33.50
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 29.94
# Epoch: 410
# [Validation]	 J_a: -30.68
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 32.76
# Epoch: 411
# [Validation]	 J_a: 24.48
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 87.91
# Epoch: 412
# [Validation]	 J_a: 171.37
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 234.80
# Epoch: 413
# [Validation]	 J_a: -30.68
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 32.75
# Epoch: 414
# [Validation]	 J_a: 105.15
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 168.58
# Epoch: 415
# [Validation]	 J_a: 51.37
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 114.80
# Epoch: 416
# [Validation]	 J_a: -6.68
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 56.76
# Epoch: 417
# [Validation]	 J_a: -1.78
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 61.65
# Epoch: 418
# [Validation]	 J_a: -35.94
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 27.50
# Epoch: 419
# [Validation]	 J_a: -15.47
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 47.96
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 41
#      39 J_alpha.backward()
#      40 # L.backward()
# ---> 41 optimizer.step()
#      42 optimizer.zero_grad()
#      44 total_loss += J_alpha.item()
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\adam.py:226, in Adam.step(self, closure)
#     214     beta1, beta2 = group["betas"]
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     223         state_steps,
#     224     )
# --> 226     adam(
#     227         params_with_grad,
#     228         grads,
#     229         exp_avgs,
#     230         exp_avg_sqs,
#     231         max_exp_avg_sqs,
#     232         state_steps,
#     233         amsgrad=group["amsgrad"],
#     234         has_complex=has_complex,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\adam.py:766, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     763 else:
#     764     func = _single_tensor_adam
# --> 766 func(
#     767     params,
#     768     grads,
#     769     exp_avgs,
#     770     exp_avg_sqs,
#     771     max_exp_avg_sqs,
#     772     state_steps,
#     773     amsgrad=amsgrad,
#     774     has_complex=has_complex,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785 )
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\optim\adam.py:379, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     376     param = torch.view_as_real(param)
#     378 # Decay the first and second moment running average coefficient
# --> 379 exp_avg.lerp_(grad, 1 - beta1)
#     380 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     382 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
# Save the list  
torch.save([J_collect, L_collect, MSE_collect], './save/cur_JLMSElist.pt')  
torch.save(model.state_dict(), "./save/model_cur.pt")
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_28656\1401418847.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_list = torch.load('./save/cur_JLMSElist.pt')

# %%
# To load the list back  
J_collect, L_collect, MSE_collect = torch.load('./save/cur_JLMSElist.pt')  
# test = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
model.load_state_dict(torch.load("./save/model_cur.pt"))
model.eval()
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_29560\632310137.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   J_collect, L_collect, MSE_collect = torch.load('./save/cur_JLMSElist.pt')
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_29560\632310137.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("./save/model_cur.pt"))
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=785, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
#   (classifier): Classifier(
#     (dense): Linear(in_features=784, out_features=256, bias=True)
#     (logits): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (regressor): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=1, bias=True)
#       (log_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Conditional generation
#
# When the model is done training you can generate samples conditionally given some normal distributed noise $z$ and a label $y$.
#
# *The model below has only trained for 10 iterations, so the perfomance is not representative*.

# %%
# 创建子图
fig, axarr = plt.subplots(3, 1, figsize=(15, 10))  # 3 行 1 列子图

EPOCH = 5001

epochs = range(1, EPOCH) 

# 第一个子图: J_collect
axarr[0].plot(epochs[100:], J_collect[100:], label='J_collect', color='b', linestyle='-', linewidth=1.5)
# axarr[0].set_title('J_alpha')
axarr[0].set_xlabel('Epochs (100 to 5000)')
axarr[0].set_ylabel('J_alpha')
axarr[0].grid()

# 第二个子图: L_collect
axarr[1].plot(epochs[100:], L_collect[100:], label='L_collect', color='g', linestyle='-', linewidth=1.5)
# axarr[1].set_title('L')
axarr[1].set_xlabel('Epochs (100 to 5000)')
axarr[1].set_ylabel('L')
axarr[1].grid()

# 第三个子图: MSE_collect
axarr[2].plot(epochs[100:], np.log(MSE_collect[100:]), label='log(MSE_collect)', color='r', linestyle='-', linewidth=1.5)
# axarr[2].set_title('MSE_collect')
axarr[2].set_xlabel('Epochs (100 to 5000)')
axarr[2].set_ylabel('Log(alpha * MSE)')
axarr[2].grid()

for i in range(3):
    axarr[i].set_xlim(100, 5050)

fig.suptitle("Loss value over epochs (Curvature)", fontsize=16)

# 调整子图布局
plt.tight_layout()

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import torch
from torch.autograd import Variable

# Initialize the figure and 1x2 axes array
fig, axarr = plt.subplots(1, 2, figsize=(16, 8), subplot_kw={'projection': '3d'})

# Set the range for T and K
T = np.linspace(0.1, 0.6, 28)
K = np.linspace(0.7, 1.3, 28)
K, T = np.meshgrid(K, T)

y_values = y_values = [0.002, cur_0.max()]
z = Variable(torch.randn(1, z_dim))

model.eval()
for i, y_value in enumerate(y_values):
    # Set y to a specific value for each sample
    y = Variable(torch.tensor([y_value]).repeat(1, 1))

    # Generate samples from the model
    x_mu = model.sample(z, y)
    samples = x_mu.data.view(-1, 1, 28, 28).numpy()

    # Plot on the corresponding subplot
    ax = axarr[i]  # Select left or right subplot
    surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')

    # Set title and adjust z-axis limits for consistency
    ax.set_title(f'''to generate cur: {y_value}\n 
                 regress cur: {model.regress(x_mu)[0].t()[0][0]}\n 
                 cur_mu: {model.regress(x_mu)[1].t()[0][0]}\n 
                 cur_std: {model.regress(x_mu)[2].mul(0.5).exp_().t()[0][0]}''',
                 linespacing=0.4, fontsize=16)
    # ax.set_zlim(0.4, 0.6)  # Adjust the z-axis limits to be consistent across all plots

# Show the final figure with all subplots
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
# import torch
# from torch.autograd import Variable

# # Initialize the figure and 2x5 axes array
# fig, axarr = plt.subplots(2, 5, figsize=(18, 10), subplot_kw={'projection': '3d'})

# # Set the range for T and K
# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# T, K = np.meshgrid(T, K)

# y_values = np.linspace(cur_0.min(), cur_0.max(), 10)
# z = Variable(torch.randn(1, z_dim))

# model.eval()
# for i, y_value in enumerate(y_values):
#     # Set y to a specific value for each sample
#     y = Variable(torch.tensor([y_value]).repeat(1, 1))
#     print("to generate y:", y.t()/10)

#     # Generate samples from the model
#     x_mu = model.sample(z, y)
#     print("real y:", x_mu.mean(dim=1).t()/10)
#     print("regress y:", model.regress(x_mu)[0].t())
#     print("y_mu:", model.regress(x_mu)[1].t())
#     print("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     print()
#     samples = x_mu.data.view(-1, 1, 28, 28).numpy()

#     # Determine subplot position (row, column)
#     row, col = divmod(i, 5)
#     ax = axarr[row, col]
    
#     # Plot the surface
#     surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')

#     # Set title and adjust z-axis limits for consistency
#     ax.set_title("to generate y:", y.t())
#     ax.set_title("real y:", x_mu.mean(dim=1).t())
#     ax.set_title("regress y:", model.regress(x_mu)[0].t())
#     ax.set_title("y_mu:", model.regress(x_mu)[1].t())
#     ax.set_title("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     ax.set_zlim(-0.2, 0.8)  # Adjust the z-axis limits to be consistent across all plots

# # Show the final figure with all subplots
# plt.tight_layout()
# plt.show()
# Out:
# to generate y: tensor([[-0.1858]], dtype=torch.float64)
# real y: tensor([0.0408], grad_fn=<DivBackward0>)
# regress y: tensor([[-1.8437]], grad_fn=<TBackward0>)
# y_mu: tensor([[-1.8437]], grad_fn=<TBackward0>)
# y_std: tensor([[1.0541e-15]], grad_fn=<TBackward0>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 41
#      38 surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')
#      40 # Set title and adjust z-axis limits for consistency
# ---> 41 ax.set_title("to generate y:", y.t())
#      42 ax.set_title("real y:", x_mu.mean(dim=1).t())
#      43 ax.set_title("regress y:", model.regress(x_mu)[0].t())
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2937, in Axes3D.set_title(self, label, fontdict, loc, **kwargs)
#    2935 def set_title(self, label, fontdict=None, loc='center', **kwargs):
#    2936     # docstring inherited
# -> 2937     ret = super().set_title(label, fontdict=fontdict, loc=loc, **kwargs)
#    2938     (x, y) = self.title.get_position()
#    2939     self.title.set_y(0.92 * y)
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\axes\_axes.py:205, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     203 title.update(default)
#     204 if fontdict is not None:
# --> 205     title.update(fontdict)
#     206 title._internal_update(kwargs)
#     207 return title
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\text.py:197, in Text.update(self, kwargs)
#     194 def update(self, kwargs):
#     195     # docstring inherited
#     196     ret = []
# --> 197     kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198     sentinel = object()  # bbox can be None, so use another sentinel.
#     199     # Update fontproperties first, as it has lowest priority.
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\cbook.py:1840, in normalize_kwargs(kw, alias_mapping)
#    1837 canonical_to_seen = {}
#    1838 ret = {}  # output dictionary
# -> 1840 for k, v in kw.items():
#    1841     canonical = to_canonical.get(k, k)
#    1842     if canonical in canonical_to_seen:
#
# AttributeError: 'Tensor' object has no attribute 'items'

# %%
# !3 lines

# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
# import torch
# from torch.autograd import Variable

# # Initialize figure and 2x5 axes array
# fig, axarr = plt.subplots(3, 10, figsize=(30, 15), subplot_kw={'projection': '3d'})

# # Set the range for T and K
# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# T, K = np.meshgrid(T, K)

# z = Variable(torch.randn(16, z_dim))
# if cuda:
#     z = z.cuda(device=0)

# model.eval()
# for dim in range(3):  # Loop over each dimension of the 3D y
#     level_min, level_max = level.min().item(), level.max().item()
#     y_min = tar[:, dim].min()
#     y_max = tar[:, dim].max()
#     y_values = np.linspace(y_min, y_max, 10)
#     for i, y_value in enumerate(y_values):
#         # Set y to a specific value for the current dimension, keep others fixed
#         y = Variable(torch.zeros(16, 3))  # Initialize y as a 3D tensor
#         y[:, 0] = tar[:, 0].mean()
#         y[:, 1] = tar[:, 1].mean()
#         y[:, 2] = tar[:, 2].mean()
#         y[:, dim] = y_value  # Set only the current dimension to y_value
#         if cuda:
#             y = y.cuda(device=0)

#         # Generate samples from the model
#         x_mu = model.sample(z, y)

#         samples = x_mu.data.view(-1, 1, 28, 28).cpu().numpy()

#         # Determine subplot position (row, column)
#         row = dim  # Row for the specific y dimension
#         col = i    # Column for the y_value within that dimension
#         ax = axarr[row, col]

#         # Plot the surface
#         surf = ax.plot_surface(K, T, samples[0, 0, :, :].t(), cmap='viridis')

#         # Set title and adjust z-axis limits for consistency
#         ax.set_title(f'y_dim {dim+1} value = {y_value:.2f}')
#         ax.set_zlim(0, 1)  # Adjust the z-axis limits to be consistent across all plots
        
#     print("Real y:", y.t())
#     print("Regressed y:", model.regress(x_mu)[0].t())
#     print("y_mu:", model.regress(x_mu)[1].t())
#     print("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     print()

# # Show the final figure with all subplots
# plt.tight_layout()
# plt.show()
# Out:
# Real y: tensor([[0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892,
#          0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7
.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01,
#          5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01,
#          5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01],
#         [7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00,
#          7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00,
#          7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00],
#         [5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03,
#          5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03,
#          5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03]], device='cuda:0')
# Regressed y: tensor([[ 0.8372,  0.8255,  0.8187,  0.8246,  0.8305,  0.8375,  0.8331,  0.8314,
#           0.8294,  0.8267,  0.8305,  0.8303,  0.8314,  0.8397,  0.8246,  0.8238],
#         [ 6.9768,  6.8157,  6.7542,  6.8749,  6.8412,  6.9442,  6.8917,  6.9129,
#           6.8723,  6.8571,  6.9311,  6.8411,  6.8824,  6.9325,  6.8080,  6.8716],
#         [-0.8013, -0.7565, -0.7474, -0.7771, -0.7782, -0.7807, -0.7860, -0.7899,
#          -0.7824, -0.7912, -0.7926, -0.7642, -0.7586, -0.7744, -0.7651, -0.8036]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.8372,  0.8255,  0.8187,  0.8246,  0.8305,  0.8375,  0.8331,  0.8314,
#           0.8294,  0.8267,  0.8305,  0.8303,  0.8314,  0.8397,  0.8246,  0.8238],
#         [ 6.9768,  6.8157,  6.7542,  6.8749,  6.8412,  6.9442,  6.8917,  6.9129,
#           6.8723,  6.8571,  6.9311,  6.8411,  6.8824,  6.9325,  6.8080,  6.8716],
#         [-0.8013, -0.7565, -0.7474, -0.7771, -0.7782, -0.7807, -0.7860, -0.7899,
#          -0.7824, -0.7912, -0.7926, -0.7642, -0.7586, -0.7744, -0.7651, -0.8036]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_std: tensor([[1.9194e-14, 2.5151e-14, 3.0559e-14, 2.4013e-14, 2.8145e-14, 1.9162e-14,
#          2.3619e-14, 2.3527e-14, 2.4859e-14, 3.0845e-14, 2.2212e-14, 2.7680e-14,
#          1.9492e-14, 1.8285e-14, 2.6984e-14, 3.3476e-14],
#         [6.9120e-12, 8.3619e-12, 9.7299e-12, 8.1071e-12, 9.3862e-12, 6.8488e-12,
#          8.1340e-12, 8.0987e-12, 8.4176e-12, 1.0150e-11, 7.7092e-12, 9.2235e-12,
#          6.8021e-12, 6.5917e-12, 8.8923e-12, 1.0903e-11],
#         [5.1445e-09, 5.7828e-09, 6.4577e-09, 5.7344e-09, 6.3830e-09, 5.0511e-09,
#          5.7557e-09, 5.7683e-09, 5.9032e-09, 6.8451e-09, 5.5738e-09, 6.2679e-09,
#          4.9575e-09, 4.8733e-09, 6.0816e-09, 7.2917e-09]], device='cuda:0',
#        grad_fn=<TBackward0>)
#
# Real y: tensor([[0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850,
#          0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850],
#         [0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451,
#          0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451],
#         [1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862,
#          1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862]],
#        device='cuda:0')
# Regressed y: tensor([[0.5524, 0.5454, 0.5440, 0.5521, 0.5484, 0.5512, 0.5481, 0.5490, 0.5475,
#          0.5471, 0.5563, 0.5394, 0.5563, 0.5455, 0.5443, 0.5447],
#         [1.2639, 1.1062, 1.1026, 1.1967, 1.2081, 1.1108, 1.1819, 1.2309, 1.2742,
#          1.0953, 1.2255, 1.1010, 1.2364, 1.1687, 1.1642, 1.1583],
#         [0.5954, 0.6517, 0.6541, 0.6608, 0.5985, 0.6269, 0.6159, 0.5815, 0.6184,
#          0.6229, 0.5919, 0.6334, 0.6142, 0.6139, 0.6266, 0.5822]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_mu: tensor([[0.5524, 0.5454, 0.5440, 0.5521, 0.5484, 0.5512, 0.5481, 0.5490, 0.5475,
#          0.5471, 0.5563, 0.5394, 0.5563, 0.5455, 0.5443, 0.5447],
#         [1.2639, 1.1062, 1.1026, 1.1967, 1.2081, 1.1108, 1.1819, 1.2309, 1.2742,
#          1.0953, 1.2255, 1.1010, 1.2364, 1.1687, 1.1642, 1.1583],
#         [0.5954, 0.6517, 0.6541, 0.6608, 0.5985, 0.6269, 0.6159, 0.5815, 0.6184,
#          0.6229, 0.5919, 0.6334, 0.6142, 0.6139, 0.6266, 0.5822]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_std: tensor([[3.9230e-11, 4.1656e-11, 4.5526e-11, 3.5154e-11, 5.1829e-11, 4.9509e-11,
#          4.2881e-11, 4.8927e-11, 3.5710e-11, 5.4023e-11, 4.9851e-11, 4.6427e-11,
#          3.7209e-11, 4.9972e-11, 4.6168e-11, 5.9095e-11],
#         [1.4736e-09, 1.5012e-09, 1.6177e-09, 1.3157e-09, 1.8504e-09, 1.7434e-09,
#          1.5645e-09, 1.7718e-09, 1.3603e-09, 1.8756e-09, 1.7933e-09, 1.6525e-09,
#          1.3963e-09, 1.7816e-09, 1.6613e-09, 2.0552e-09],
#         [7.3315e-08, 6.9996e-08, 7.4155e-08, 6.3897e-08, 8.6524e-08, 7.9335e-08,
#          7.4815e-08, 8.4674e-08, 6.8555e-08, 8.4080e-08, 8.4495e-08, 7.6286e-08,
#          6.8927e-08, 8.2745e-08, 7.7874e-08, 9.3612e-08]], device='cuda:0',
#        grad_fn=<TBackward0>)

# %%
stop!
# Out:
#   Cell In[14], line 1
#     stop!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Stacked Deep Generative Model
#
# The M1+M2 model also described in the same paper is an M1 model (VAE) with an M2 model stacked on top of it. That means that we train the a VAE end-to-end on the data given dataset, then we use the learned encoder as a feature extractor and feed the data transformed by the M1 encoder into the M2 model.
#
# We approach is somewhat similar to restricted boltzmann machines (RBMs) in the sense that we perform a layerwise training of the whole model by first training a level-1 feature extractor and stacking another model on top of this. The stacked model is therefore also more modular, but cannot be trained end-to-end, which is a downside.

# %%
from models import VariationalAutoencoder, StackedDeepGenerativeModel

features = VariationalAutoencoder([784, z_dim, h_dim])
model = StackedDeepGenerativeModel([784, y_dim, z_dim, h_dim], features)

# %% [markdown]
# Typically, you would want to load a pretrained feature extractor VAE instead.

# %%
features = torch.load("./your-pretrained-vae.pt")
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_15576\1198095296.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   features = torch.load("./your-pretrained-vae.pt")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 features = torch.load("./your-pretrained-vae.pt")
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './your-pretrained-vae.pt'

# %%
from torch.autograd import Variable

for epoch in range(10):
    model.train()
    total_loss, accuracy = (0, 0)
    for (x, y), (u, _) in zip(cycle(labelled), unlabelled):
        # Wrap in variables
        x, y, u = Variable(x), Variable(y), Variable(u)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            u = u.cuda(device=0)

        L = -elbo(x, y)
        U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        logits = model.classify(x)
        
        # Regular cross entropy
        classication_loss = torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

        J_alpha = L - alpha * classication_loss + U

        J_alpha.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.data[0]
        accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
        
    if epoch % 1 == 0:
        model.eval()
        m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, accuracy = (0, 0)
        for x, y in validation:
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            U = -elbo(x)

            logits = model.classify(x)
            classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

            J_alpha = L + alpha * classication_loss + U

            total_loss += J_alpha.data[0]

            _, pred_idx = torch.max(logits, 1)
            _, lab_idx = torch.max(y, 1)
            accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

        m = len(validation)
        print("[Validation]\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

# %% [markdown]
# ## Additional tips
#
# You can change the built-in classifier with your own, for example if you want a CNN as a classifier you can do the following.

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvolutionalClassifier(nn.Module):
    def __init__(self):
        super(ConvolutionalClassifier, self).__init__()        
        self.conv1 = nn.Conv2d(1, 64, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=3)
        self.pool = nn.MaxPool2d(kernel_size=4)

        size = int((28 - 3) + 1)//4
        size = int((size - 3) + 1)//4
                
        self.fc1 = nn.Linear(32*size**2, 50)
        self.fc2 = nn.Linear(50, 10)
        
    def forward(self, x):
        batch, *_ = x.size()
        x = x.view(-1, 1, 28, 28)
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(x.view(batch, -1))
        x = self.fc1(x)
        x = self.fc2(x)
        return F.softmax(x, dim=-1)

classifier = ConvolutionalClassifier()
model.classifier = classifier

# %%
model
# Out:
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=794, out_features=256)
#       (1): Linear(in_features=256, out_features=128)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32)
#       (log_var): Linear(in_features=128, out_features=32)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=42, out_features=128)
#       (1): Linear(in_features=128, out_features=256)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784)
#     (output_activation): Sigmoid()
#   )
#   (classifier): ConvolutionalClassifier(
#     (conv1): Conv2d (1, 64, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d (64, 32, kernel_size=(3, 3), stride=(1, 1))
#     (pool): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), dilation=(1, 1))
#     (fc1): Linear(in_features=32, out_features=50)
#     (fc2): Linear(in_features=50, out_features=10)
#   )
# )
