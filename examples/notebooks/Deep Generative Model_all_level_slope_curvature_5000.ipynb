# %%
# Imports
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import random_split
import torchvision.transforms as transforms
import torch.nn.functional as F

cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.io
import sys
sys.path.append("../../semi-supervised")

# %% [markdown]
# # Deep Generative Model
#
# In this notebook we show how you can use the deep "generative model for semi-supervised learning" as presented in [[Kingma 2014]](https://arxiv.org/abs/1406.5298). The paper posits three different models, though we are just interested in two of these: the M2 model and the M1+M2 model.
#
# The M1 model is just a variational autoencoder, so we refer to the previous notebook for more information on this. The M2 model however is an extension to the VAE to include label information for a semi-supervised objective. The structure is shown below (left: inference model, right: generative model).
#
# <img src="../images/dgm.png" width="400px"/>
#
# The point of the generative model is to seperate the partially observed label information $y$ from the latent variable $z$ in order to learn a representation that seperates these two variables. We can use this model for semi-supervised learning as the inference model must also infer the label from the data $x$ along with the latent variable $z$.

# %%
from models import DeepGenerativeModel, StackedDeepGenerativeModel

y_dim = 3
z_dim = 32
h_dim = [256, 128]

model = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
model
# Out:
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\vae.py:114: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\dgm.py:67: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=787, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=35, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
#   (classifier): Classifier(
#     (dense): Linear(in_features=784, out_features=256, bias=True)
#     (logits): Linear(in_features=256, out_features=3, bias=True)
#   )
#   (regressor): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=3, bias=True)
#       (log_var): Linear(in_features=128, out_features=3, bias=True)
#     )
#   )
# )

# %%
print(model.encoder.hidden[0])
print(model.decoder.hidden[0])
# Out:
# Linear(in_features=787, out_features=256, bias=True)
# Linear(in_features=35, out_features=128, bias=True)

# %% [markdown]
# Notice how theres now a classifier associated with model. This classifier will just be a simple model that takes the size of the first layer encoder network. We also have a larger input space on both the encoder and decoder to make room for label information, in this case 10 labels.

# %% [markdown]
# ## Training
#
# Recall the ELBO from the VAE formulation, we want to construct a similar ELBO when we include labelled data $y$. In the case that we have labels, the ELBO has a simple formulation that is similar to the one for the VAE. The difference here is that we must also have a prior over labels $p(y)$, which we choose to be uniform over the different classes.
#
# \begin{align}
# \log p(x, y) &= \log \int q(z|x, y) \frac{p(x, y, z)}{q(z|xy)} \ dz \geq \int q(z|x, y) \log \frac{p(x, y, z)}{q(z|xy)} \ dz\\
# &= \int q(z|x, y) [ \log p(x|z,y) + \log p(y) ] \ dz + \int q(z|x, y) \log \frac{p(z)}{q(z|xy)} \ dz\\
# &= \mathbb{E}_{q(z|x, y)} [ \log p(x|z,y) + \log p(y) ] - KL(p(z)||q(z|xy)) = - \mathcal{L}(x, y)
# \end{align}
#
# In the case when the labels are not observed, we can instead integrate over all of the labels to achieve the same effect.
#
# \begin{align}
# \log p(x) &= \log \sum_{y} \int q(z,y|x) \frac{p(x, y, z)}{q(z,y|x)} \ dz \geq \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz\\
# &= \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz + \sum_{y} q(y|x) \log q(y|x) \int q(z|x, y) \ dz\\
# &= \sum_{y} q(y|x) (- \mathcal{L}(x,y)) + \mathcal{H}(q(y|x)) = - \mathcal{U}(x)
# \end{align}
#
# Notice how in both cases we need to compute the labelled bound, but in the unlabelled case we need to do it $n$ times where $n$ is the number of classes. In this model, we do not learn directly from the labelled class, as there is no cross entropy term between $y$ and our model output $q(y|x)$. We therefore add an auxiliary loss to arrive at the final loss objective.
#
# $$\mathcal{J}^{\alpha} = \sum_{(x_l, y_l)}\mathcal{L}(x_l, y_l) + \alpha \cdot \mathbb{E}_{x_l, y_l}[- \log q(y_l|x_l)] + \sum_{(x_u)}\mathcal{U}(x_u)$$
#
# Where $l, u$ denotes labelled and unlabelled data respectively and $\alpha$ is a hyperparameter that denotes the reliance of labelled data.

# %%
# from datautils import get_mnist

# # Only use 10 labelled examples per class
# # The rest of the data is unlabelled.
# labelled, unlabelled, validation = get_mnist(location="./", batch_size=64, labels_per_class=10)
# alpha = 0.1 * len(unlabelled) / len(labelled)


# def binary_cross_entropy(r, x):
#     return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999))

# %% [markdown]
# # Load Data

# %%
data = scipy.io.loadmat('./data/heston_vol_images_train_30000.mat')
impliedVolsurfaces = torch.tensor(data['impliedVolsurfaces_collection']).float()

max_val = torch.max(impliedVolsurfaces)
min_val = torch.min(impliedVolsurfaces)

impliedVolsurfaces_normalized = (impliedVolsurfaces - min_val) / (max_val - min_val)

impliedVolsurfaces_normalized_flatten = impliedVolsurfaces_normalized.reshape(30000, 784)

level = torch.mean(impliedVolsurfaces_normalized_flatten, dim=1)
print("level:", level.shape, level.min(), level.max())

# slope = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=1, axis=2)) * 1000
# # K_index_s = slope.shape[2] // 2
# # slope = torch.from_numpy(slope[:, :, K_index_s, :])
# slope_ave = torch.mean(slope, dim=[2, 3]).squeeze(1)
# print("slope:", slope_ave.shape, slope_ave.min(), slope_ave.max())

# curvature = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=2, axis=2)) * 1000
# K_index_c = curvature.shape[2] // 2
# curvature = torch.from_numpy(curvature[:, :, K_index_c, :])
# curvature_ave = torch.max(curvature, dim=[2, 3]).squeeze(1)
# values, indices = curvature.reshape(30000, -1).sort()
# curvature_l3 = values[:, -3]
# # print("curvature:", curvature_ave.shape, curvature.min(), curvature.max())
# print("curvature:", curvature_l3.shape, curvature_l3.min(), curvature_l3.max())
lhs_matrix = data["lhs_matrix"]  # 形状: [30000, 6]

# 获取公式中的变量
rho = lhs_matrix[:, 0]       # 第 1 列，rho
v0 = lhs_matrix[:, 2]        # 第 3 列，v0
gamma = lhs_matrix[:, 3]     # 第 4 列，gamma

slope_0 = torch.from_numpy(rho * gamma / ( 4 * np.sqrt(v0) )).type(torch.float32)

# 计算公式
cur_0 = torch.from_numpy((gamma**2) / (24 * v0**(3/2)) * (2 - 5 * rho**2)).type(torch.float32)

# tar = level

tar = torch.stack([level, slope_0, cur_0], dim=1)
print(tar.shape)

ivs = TensorDataset(impliedVolsurfaces_normalized_flatten, tar)

torch.manual_seed(0)

total_size = len(ivs)
train_size = int(total_size * 0.7)
labelled_size = int(train_size * 1)
# labelled_size = int(train_size * 0.1)
# labelled_size = int(0)
# unlabelled_size = train_size - labelled_size
validation_size = total_size - train_size
alpha = 0.1 * train_size


# labelled_dataset, unlabelled_dataset, validation_dataset = random_split(ivs, [labelled_size, unlabelled_size, validation_size])
labelled_dataset, validation_dataset = random_split(ivs, [labelled_size,  validation_size])

BATCH_SIZE = 64
EPOCH = 5001

labelled = DataLoader(labelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
# unlabelled = DataLoader(unlabelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# level: torch.Size([30000]) tensor(0.3257) tensor(0.7892)
# torch.Size([30000, 3])

# %%
# level min max
from mpl_toolkits.mplot3d import Axes3D

T = np.linspace(0.1, 0.6, 28)
K = np.linspace(0.7, 1.3, 28)
K, T = np.meshgrid(K, T)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_0.argmin()].view(28, 28), cmap='viridis')
ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_0.argmax()].view(28, 28), cmap='viridis')

# %%
# # slope min max
# from mpl_toolkits.mplot3d import Axes3D

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmin()].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmax()].view(28, 28), cmap='viridis')

# %%
sorted
# Out:
# tensor([-0.6102, -0.6097, -0.6027,  ..., -0.0070, -0.0069, -0.0064])

# %%
# curvature min max
from mpl_toolkits.mplot3d import Axes3D

sorted, indices = slope_0.sort()
print(sorted)
print(indices)

idx = np.linspace(0, 30000-1, 5).astype(int)

T = np.linspace(0.1, 0.6, 28)
K = np.linspace(0.7, 1.3, 28)
K, T = np.meshgrid(K, T)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[10100]].view(28, 28), cmap='viridis') # sur = 0.1
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[10000]].view(28, 28), cmap='viridis')
ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[0]].view(28, 28), cmap='viridis') 
ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[20000]].view(28, 28), cmap='viridis') 
# ax.set_zlim(0.4,0.7)
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[-1]].view(28, 28), cmap='viridis') # sur = 0.1
# Out:
# tensor([-0.6102, -0.6097, -0.6027,  ..., -0.0070, -0.0069, -0.0064])
# tensor([24415, 24720, 27632,  ..., 25836, 14826, 20770])

# %%
from itertools import cycle
from inference import SVI, ImportanceWeightedSampler

# You can use importance weighted samples [Burda, 2015] to get a better estimate
# on the log-likelihood.
sampler = ImportanceWeightedSampler(mc=1, iw=1)

if cuda: model = model.cuda()
elbo = SVI(model, likelihood=F.mse_loss, sampler=sampler)

# %% [markdown]
# The library is conventially packed with the `SVI` method that does all of the work of calculating the lower bound for both labelled and unlabelled data depending on whether the label is given. It also manages to perform the enumeration of all the labels.
#
# Remember that the labels have to be in a *one-hot encoded* format in order to work with SVI.

# %%
from torch.autograd import Variable

J_collect = []
L_collect = []
MSE_collect = []

for epoch in range(1, EPOCH):
    model.train()
    total_loss, L_sum, MSE_sum = (0, 0, 0)
    for x, y in labelled:
        # Wrap in variables
        # x, y, u = Variable(x), Variable(y), Variable(u)
        # y = y.unsqueeze(1)
        x, y = Variable(x), Variable(y)
        # print(x, y)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            # u = u.cuda(device=0)

        L = -elbo(x, y)
        # U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        pred_y, y_mu, y_logvar = model.regress(x)
        # print(pred_y.shape)
        # pred_y = pred_y.squeeze(1)
        # print(pred_y.shape)
        # print(pred_y.sum())
        
        # Regular cross entropy
        # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
        # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
        regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()

        J_alpha = L + alpha * regression_loss

        J_alpha.backward()
        # L.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.item()
        # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
    if epoch % 100 == 0:
        print("Epoch: {}, ELBO now is {}, regression loss is {}".format(epoch, L, regression_loss))
        print("pred_y:", pred_y.t())
        print("y_mu:", y_mu.t())
        print("y_std:", y_logvar.mul(0.5).exp_().t())
        print('real y:', y.view(-1))
        
    if epoch % 1 == 0:
        model.eval()
        # m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        # print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, L_sum, MSE_sum = (0, 0, 0)
        for x, y in validation:
            # y = y.unsqueeze(1)
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            # U = -elbo(x)

            # logits = model.classify(x)
            pred_y, y_mu, y_logvar = model.regress(x)

            # classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()
            # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
            # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
            # print(pred_y.shape)
            # pred_y = pred_y.squeeze(1)
            # print(pred_y.shape)
            regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()
            J_alpha = L + alpha * regression_loss



            total_loss += J_alpha.item()
            L_sum += L.item()
            MSE_sum += regression_loss.item()

            # print(J_alpha.item())
            # print(L.item())
            # print(alpha * regression_loss.item())

            # _, pred_idx = torch.max(logits, 1)
            # _, lab_idx = torch.max(y, 1)
            # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

    
        m = len(validation)
        print("[Validation]\t J_a: {:.2f}".format(total_loss / m))
        print("[Validation]\t L: {:.4f}".format(L_sum / m)) # !didn't sum over L, need to be changed
        print("[Validation]\t alpha * MSE: {:.2f}".format(alpha * MSE_sum / m)) # !didn't sum over regression_loss, need to be changed

        J_collect.append(total_loss / m)
        L_collect.append(L_sum / m)
        MSE_collect.append(MSE_sum / m)
        # print("[Validation]\t L: {:.2f}".format(total_loss / m))
# Out:
# Epoch: 1
# [Validation]	 J_a: 8609.80
# [Validation]	 L: -3.0174
# [Validation]	 alpha * MSE: 8612.82
# Epoch: 2
# [Validation]	 J_a: 4649.19
# [Validation]	 L: -3.0199
# [Validation]	 alpha * MSE: 4652.21
# Epoch: 3
# [Validation]	 J_a: 2472.85
# [Validation]	 L: -3.0220
# [Validation]	 alpha * MSE: 2475.88
# Epoch: 4
# [Validation]	 J_a: 12109.06
# [Validation]	 L: -3.0235
# [Validation]	 alpha * MSE: 12112.09
# Epoch: 5
# [Validation]	 J_a: 1118.63
# [Validation]	 L: -3.0241
# [Validation]	 alpha * MSE: 1121.65
# Epoch: 6
# [Validation]	 J_a: 1455.11
# [Validation]	 L: -3.0249
# [Validation]	 alpha * MSE: 1458.13
# Epoch: 7
# [Validation]	 J_a: 6716.28
# [Validation]	 L: -3.0244
# [Validation]	 alpha * MSE: 6719.30
# Epoch: 8
# [Validation]	 J_a: 2779.79
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 2782.82
# Epoch: 9
# [Validation]	 J_a: 5527.95
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 5530.97
# Epoch: 10
# [Validation]	 J_a: 2188.42
# [Validation]	 L: -3.0252
# [Validation]	 alpha * MSE: 2191.44
# Epoch: 11
# [Validation]	 J_a: 1280.51
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 1283.54
# Epoch: 12
# [Validation]	 J_a: 2318.11
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 2321.13
# Epoch: 13
# [Validation]	 J_a: 839.78
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 842.80
# Epoch: 14
# [Validation]	 J_a: 1294.41
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 1297.44
# Epoch: 15
# [Validation]	 J_a: 786.90
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 789.93
# Epoch: 16
# [Validation]	 J_a: 1175.48
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 1178.50
# Epoch: 17
# [Validation]	 J_a: 343.78
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 346.81
# Epoch: 18
# [Validation]	 J_a: 4853.39
# [Validation]	 L: -3.0249
# [Validation]	 alpha * MSE: 4856.41
# Epoch: 19
# [Validation]	 J_a: 2280.92
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 2283.95
# Epoch: 20
# [Validation]	 J_a: 814.90
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 817.92
# Epoch: 21
# [Validation]	 J_a: 382.78
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 385.81
# Epoch: 22
# [Validation]	 J_a: 554.62
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 557.64
# Epoch: 23
# [Validation]	 J_a: 1231.36
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 1234.39
# Epoch: 24
# [Validation]	 J_a: 697.64
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 700.67
# Epoch: 25
# [Validation]	 J_a: 633.96
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 636.99
# Epoch: 26
# [Validation]	 J_a: 288.20
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 291.23
# Epoch: 27
# [Validation]	 J_a: 5876.07
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 5879.09
# Epoch: 28
# [Validation]	 J_a: 1547.14
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 1550.16
# Epoch: 29
# [Validation]	 J_a: 194.50
# [Validation]	 L: -3.0252
# [Validation]	 alpha * MSE: 197.53
# Epoch: 30
# [Validation]	 J_a: 206.53
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 209.55
# Epoch: 31
# [Validation]	 J_a: 714.34
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 717.37
# Epoch: 32
# [Validation]	 J_a: 1071.19
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 1074.21
# Epoch: 33
# [Validation]	 J_a: 721.39
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 724.41
# Epoch: 34
# [Validation]	 J_a: 423.43
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 426.46
# Epoch: 35
# [Validation]	 J_a: 505.05
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 508.07
# Epoch: 36
# [Validation]	 J_a: 442.00
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 445.02
# Epoch: 37
# [Validation]	 J_a: 143.47
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 146.49
# Epoch: 38
# [Validation]	 J_a: 127.85
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 130.88
# Epoch: 39
# [Validation]	 J_a: 160.71
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 163.74
# Epoch: 40
# [Validation]	 J_a: 296.48
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 299.51
# Epoch: 41
# [Validation]	 J_a: 1078.72
# [Validation]	 L: -3.0248
# [Validation]	 alpha * MSE: 1081.75
# Epoch: 42
# [Validation]	 J_a: 491.24
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 494.26
# Epoch: 43
# [Validation]	 J_a: 135.63
# [Validation]	 L: -3.0265
# [Validation]	 alpha * MSE: 138.66
# Epoch: 44
# [Validation]	 J_a: 198.41
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 201.43
# Epoch: 45
# [Validation]	 J_a: 410.94
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 413.96
# Epoch: 46
# [Validation]	 J_a: 114.54
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 117.56
# Epoch: 47
# [Validation]	 J_a: 687.78
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 690.80
# Epoch: 48
# [Validation]	 J_a: 347.93
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 350.96
# Epoch: 49
# [Validation]	 J_a: 1030.11
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 1033.14
# Epoch: 50
# [Validation]	 J_a: 155.89
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 158.92
# Epoch: 51
# [Validation]	 J_a: 469.53
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 472.56
# Epoch: 52
# [Validation]	 J_a: 911.93
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 914.96
# Epoch: 53
# [Validation]	 J_a: 124.36
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 127.38
# Epoch: 54
# [Validation]	 J_a: 376.44
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 379.47
# Epoch: 55
# [Validation]	 J_a: 206.08
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 209.10
# Epoch: 56
# [Validation]	 J_a: 903.71
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 906.73
# Epoch: 57
# [Validation]	 J_a: 273.36
# [Validation]	 L: -3.0252
# [Validation]	 alpha * MSE: 276.39
# Epoch: 58
# [Validation]	 J_a: 128.40
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 131.42
# Epoch: 59
# [Validation]	 J_a: 213.51
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 216.54
# Epoch: 60
# [Validation]	 J_a: 208.10
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 211.13
# Epoch: 61
# [Validation]	 J_a: 1786.03
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 1789.06
# Epoch: 62
# [Validation]	 J_a: 128.71
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 131.73
# Epoch: 63
# [Validation]	 J_a: 622.11
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 625.13
# Epoch: 64
# [Validation]	 J_a: 105.37
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 108.40
# Epoch: 65
# [Validation]	 J_a: 118.11
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 121.13
# Epoch: 66
# [Validation]	 J_a: 649.09
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 652.11
# Epoch: 67
# [Validation]	 J_a: 102.55
# [Validation]	 L: -3.0265
# [Validation]	 alpha * MSE: 105.58
# Epoch: 68
# [Validation]	 J_a: 481.00
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 484.03
# Epoch: 69
# [Validation]	 J_a: 128.77
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 131.80
# Epoch: 70
# [Validation]	 J_a: 1053.22
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 1056.24
# Epoch: 71
# [Validation]	 J_a: 97.10
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 100.13
# Epoch: 72
# [Validation]	 J_a: 478.36
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 481.38
# Epoch: 73
# [Validation]	 J_a: 163.60
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 166.63
# Epoch: 74
# [Validation]	 J_a: 83.91
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 86.94
# Epoch: 75
# [Validation]	 J_a: 185.00
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 188.02
# Epoch: 76
# [Validation]	 J_a: 76.31
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 79.34
# Epoch: 77
# [Validation]	 J_a: 530.92
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 533.95
# Epoch: 78
# [Validation]	 J_a: 262.67
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 265.70
# Epoch: 79
# [Validation]	 J_a: 377.75
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 380.77
# Epoch: 80
# [Validation]	 J_a: 67.86
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 70.89
# Epoch: 81
# [Validation]	 J_a: 594.65
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 597.68
# Epoch: 82
# [Validation]	 J_a: 467.63
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 470.65
# Epoch: 83
# [Validation]	 J_a: 600.92
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 603.94
# Epoch: 84
# [Validation]	 J_a: 390.82
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 393.84
# Epoch: 85
# [Validation]	 J_a: 75.07
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 78.09
# Epoch: 86
# [Validation]	 J_a: 177.74
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 180.77
# Epoch: 87
# [Validation]	 J_a: 63.54
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 66.57
# Epoch: 88
# [Validation]	 J_a: 948.88
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 951.91
# Epoch: 89
# [Validation]	 J_a: 135.60
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 138.63
# Epoch: 90
# [Validation]	 J_a: 71.95
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 74.97
# Epoch: 91
# [Validation]	 J_a: 132.63
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 135.66
# Epoch: 92
# [Validation]	 J_a: 1597.24
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 1600.26
# Epoch: 93
# [Validation]	 J_a: 252.90
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 255.92
# Epoch: 94
# [Validation]	 J_a: 172.91
# [Validation]	 L: -3.0252
# [Validation]	 alpha * MSE: 175.93
# Epoch: 95
# [Validation]	 J_a: 109.07
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 112.09
# Epoch: 96
# [Validation]	 J_a: 68.13
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 71.16
# Epoch: 97
# [Validation]	 J_a: 406.34
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 409.36
# Epoch: 98
# [Validation]	 J_a: 144.97
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 147.99
# Epoch: 99
# [Validation]	 J_a: 98.81
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 101.84
# Epoch: 100, ELBO now is -3.0351107120513916, regression loss is 0.0035627344623208046
# pred_y: tensor([[ 0.4762,  0.5260,  0.6129,  0.6577,  0.5363,  0.6277,  0.6060,  0.6334],
#         [-0.4503, -0.0960, -0.0684, -0.1399, -0.0255, -0.3248, -0.2730, -0.0324],
#         [-0.5122,  0.8401,  0.0510,  0.4437,  0.0146, -0.3173,  0.0138,  0.0176]],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.4762,  0.5260,  0.6129,  0.6577,  0.5363,  0.6277,  0.6060,  0.6334],
#         [-0.4503, -0.0959, -0.0684, -0.1399, -0.0256, -0.3248, -0.2730, -0.0324],
#         [-0.5123,  0.8392,  0.0507,  0.4438,  0.0151, -0.3174,  0.0138,  0.0177]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[4.1198e-05, 7.5713e-05, 1.2227e-05, 9.0525e-06, 5.6574e-05, 5.6369e-06,
#          1.3132e-05, 1.1051e-05],
#         [6.2452e-05, 9.3671e-05, 1.8527e-05, 1.3017e-05, 8.0396e-05, 8.9524e-06,
#          2.0440e-05, 1.6689e-05],
#         [3.8953e-04, 6.2538e-04, 1.3361e-04, 1.0048e-04, 3.8891e-04, 7.1897e-05,
#          1.2914e-04, 1.0595e-04]], grad_fn=<TBackward0>)
# real y: tensor([ 0.4774, -0.4272, -0.4768,  0.5278, -0.0874,  0.8200,  0.6145, -0.0575,
#          0.0550,  0.6583, -0.1285,  0.4482,  0.5416, -0.0192,  0.0240,  0.6308,
#         -0.3093, -0.3165,  0.6063, -0.2583,  0.0177,  0.6390, -0.0256,  0.0348])
# Epoch: 100
# [Validation]	 J_a: 135.00
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 138.02
# Epoch: 101
# [Validation]	 J_a: 86.55
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 89.58
# Epoch: 102
# [Validation]	 J_a: 256.45
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 259.47
# Epoch: 103
# [Validation]	 J_a: 90.12
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 93.15
# Epoch: 104
# [Validation]	 J_a: 81.38
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 84.41
# Epoch: 105
# [Validation]	 J_a: 339.68
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 342.71
# Epoch: 106
# [Validation]	 J_a: 81.49
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 84.52
# Epoch: 107
# [Validation]	 J_a: 73.38
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 76.40
# Epoch: 108
# [Validation]	 J_a: 262.25
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 265.28
# Epoch: 109
# [Validation]	 J_a: 87.76
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 90.79
# Epoch: 110
# [Validation]	 J_a: 69.39
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 72.42
# Epoch: 111
# [Validation]	 J_a: 548.43
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 551.45
# Epoch: 112
# [Validation]	 J_a: 109.59
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 112.62
# Epoch: 113
# [Validation]	 J_a: 1633.79
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 1636.82
# Epoch: 114
# [Validation]	 J_a: 172.65
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 175.67
# Epoch: 115
# [Validation]	 J_a: 201.48
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 204.51
# Epoch: 116
# [Validation]	 J_a: 161.65
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 164.68
# Epoch: 117
# [Validation]	 J_a: 89.64
# [Validation]	 L: -3.0251
# [Validation]	 alpha * MSE: 92.66
# Epoch: 118
# [Validation]	 J_a: 182.27
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 185.30
# Epoch: 119
# [Validation]	 J_a: 86.51
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 89.54
# Epoch: 120
# [Validation]	 J_a: 95.65
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 98.68
# Epoch: 121
# [Validation]	 J_a: 286.83
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 289.85
# Epoch: 122
# [Validation]	 J_a: 59.13
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 62.16
# Epoch: 123
# [Validation]	 J_a: 125.48
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 128.51
# Epoch: 124
# [Validation]	 J_a: 49.96
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 52.99
# Epoch: 125
# [Validation]	 J_a: 515.93
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE:
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 53.56
# Epoch: 198
# [Validation]	 J_a: 43.56
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 46.58
# Epoch: 199
# [Validation]	 J_a: 55.22
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 58.24
# Epoch: 200, ELBO now is -2.960449695587158, regression loss is 0.0012323592090979218
# pred_y: tensor([[ 0.4881,  0.5975,  0.5585,  0.5985,  0.5717,  0.6247,  0.5808,  0.6788],
#         [-0.3604, -0.0644, -0.0714, -0.3816, -0.1465, -0.1061, -0.0502, -0.0535],
#         [-0.1500,  0.0524, -0.0128, -0.5712,  0.1414,  0.2697,  0.0294,  0.1232]],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.4881,  0.5976,  0.5585,  0.5985,  0.5717,  0.6247,  0.5807,  0.6788],
#         [-0.3604, -0.0644, -0.0714, -0.3816, -0.1465, -0.1061, -0.0502, -0.0535],
#         [-0.1499,  0.0524, -0.0127, -0.5712,  0.1414,  0.2697,  0.0293,  0.1232]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[4.5103e-06, 1.1838e-05, 2.3126e-05, 8.8904e-07, 1.0140e-05, 4.7384e-06,
#          1.5989e-05, 2.9561e-06],
#         [8.0832e-06, 1.8516e-05, 3.6192e-05, 1.9621e-06, 1.6521e-05, 7.2980e-06,
#          2.5302e-05, 4.9118e-06],
#         [4.0626e-05, 7.7817e-05, 1.2926e-04, 6.6792e-06, 8.5837e-05, 4.4037e-05,
#          1.0499e-04, 2.8587e-05]], grad_fn=<TBackward0>)
# real y: tensor([ 0.4937, -0.3601, -0.1272,  0.6024, -0.0640,  0.0576,  0.5632, -0.0708,
#         -0.0198,  0.6056, -0.3784, -0.5634,  0.5767, -0.1426,  0.1384,  0.6307,
#         -0.1032,  0.2681,  0.5844, -0.0473,  0.0302,  0.6834, -0.0504,  0.1402])
# Epoch: 200
# [Validation]	 J_a: 38.11
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 41.13
# Epoch: 201
# [Validation]	 J_a: 180.64
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 183.66
# Epoch: 202
# [Validation]	 J_a: 201.71
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 204.74
# Epoch: 203
# [Validation]	 J_a: 154.84
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 157.86
# Epoch: 204
# [Validation]	 J_a: 100.70
# [Validation]	 L: -3.0253
# [Validation]	 alpha * MSE: 103.72
# Epoch: 205
# [Validation]	 J_a: 39.74
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 42.77
# Epoch: 206
# [Validation]	 J_a: 435.30
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 438.33
# Epoch: 207
# [Validation]	 J_a: 88.95
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 91.98
# Epoch: 208
# [Validation]	 J_a: 64.84
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 67.87
# Epoch: 209
# [Validation]	 J_a: 239.24
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 242.26
# Epoch: 210
# [Validation]	 J_a: 135.44
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 138.47
# Epoch: 211
# [Validation]	 J_a: 208.78
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 211.81
# Epoch: 212
# [Validation]	 J_a: 137.20
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 140.23
# Epoch: 213
# [Validation]	 J_a: 111.72
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 114.74
# Epoch: 214
# [Validation]	 J_a: 45.37
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 48.39
# Epoch: 215
# [Validation]	 J_a: 1128.16
# [Validation]	 L: -3.0248
# [Validation]	 alpha * MSE: 1131.19
# Epoch: 216
# [Validation]	 J_a: 60.14
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE:
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 60.07
# Epoch: 293
# [Validation]	 J_a: 62.71
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 65.73
# Epoch: 294
# [Validation]	 J_a: 32.33
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 35.36
# Epoch: 295
# [Validation]	 J_a: 49.16
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 52.18
# Epoch: 296
# [Validation]	 J_a: 93.44
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 96.47
# Epoch: 297
# [Validation]	 J_a: 127.35
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 130.37
# Epoch: 298
# [Validation]	 J_a: 31.11
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 34.13
# Epoch: 299
# [Validation]	 J_a: 229.12
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 232.14
# Epoch: 300, ELBO now is -3.026059865951538, regression loss is 0.005391417071223259
# pred_y: tensor([[ 0.6098,  0.5468,  0.5347,  0.6510,  0.5907,  0.6082,  0.5768,  0.6950],
#         [-0.1656, -0.1281, -0.2184, -0.1667, -0.3996, -0.0598, -0.1657, -0.1994],
#         [-0.0918,  0.7071,  0.2843, -0.0785, -0.4733,  0.3893,  0.1869,  0.0062]],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.6098,  0.5468,  0.5347,  0.6510,  0.5907,  0.6082,  0.5768,  0.6950],
#         [-0.1656, -0.1281, -0.2184, -0.1667, -0.3996, -0.0598, -0.1657, -0.1994],
#         [-0.0917,  0.7071,  0.2843, -0.0785, -0.4733,  0.3893,  0.1870,  0.0062]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.4468e-06, 3.8008e-07, 5.7366e-07, 6.7271e-07, 3.0823e-08, 1.4387e-06,
#          1.2475e-06, 1.7731e-07],
#         [5.2609e-06, 1.2449e-06, 2.1365e-06, 2.5588e-06, 1.9416e-07, 4.2791e-06,
#          4.3124e-06, 7.5620e-07],
#         [2.2094e-05, 1.9069e-05, 1.8690e-05, 1.4071e-05, 1.2295e-06, 3.5998e-05,
#          2.7196e-05, 5.6546e-06]], grad_fn=<TBackward0>)
# real y: tensor([ 0.6114, -0.1674, -0.0757,  0.5455, -0.1258,  0.7593,  0.5343, -0.2167,
#          0.3035,  0.6527, -0.1682, -0.0604,  0.5907, -0.3983, -0.4492,  0.6084,
#         -0.0567,  0.4003,  0.5773, -0.1646,  0.2060,  0.6957, -0.2024,  0.0308])
# Epoch: 300
# [Validation]	 J_a: 76.17
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 79.19
# Epoch: 301
# [Validation]	 J_a: 155.17
# [Validation]	 L: -3.0265
# [Validation]	 alpha * MSE: 158.20
# Epoch: 302
# [Validation]	 J_a: 147.86
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 150.89
# Epoch: 303
# [Validation]	 J_a: 58.93
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 61.96
# Epoch: 304
# [Validation]	 J_a: 242.04
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 245.07
# Epoch: 305
# [Validation]	 J_a: 124.95
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 127.98
# Epoch: 306
# [Validation]	 J_a: 179.87
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 182.89
# Epoch: 307
# [Validation]	 J_a: 221.18
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 224.20
# Epoch: 308
# [Validation]	 J_a: 27.57
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE:
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 371.65
# Epoch: 384
# [Validation]	 J_a: 75.43
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 78.45
# Epoch: 385
# [Validation]	 J_a: 43.64
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 46.67
# Epoch: 386
# [Validation]	 J_a: 93.98
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 97.01
# Epoch: 387
# [Validation]	 J_a: 44.32
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 47.34
# Epoch: 388
# [Validation]	 J_a: 91.21
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 94.23
# Epoch: 389
# [Validation]	 J_a: 474.08
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 477.11
# Epoch: 390
# [Validation]	 J_a: 37.19
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 40.21
# Epoch: 391
# [Validation]	 J_a: 40.09
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 43.11
# Epoch: 392
# [Validation]	 J_a: 93.65
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 96.68
# Epoch: 393
# [Validation]	 J_a: 109.86
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 112.89
# Epoch: 394
# [Validation]	 J_a: 88.76
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 91.79
# Epoch: 395
# [Validation]	 J_a: 88.38
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 91.40
# Epoch: 396
# [Validation]	 J_a: 163.13
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 166.16
# Epoch: 397
# [Validation]	 J_a: 83.57
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 86.60
# Epoch: 398
# [Validation]	 J_a: 36.01
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 39.03
# Epoch: 399
# [Validation]	 J_a: 388.94
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 391.96
# Epoch: 400, ELBO now is -2.968264102935791, regression loss is 0.0018842656863853335
# pred_y: tensor([[ 0.6142,  0.5611,  0.6370,  0.6335,  0.5033,  0.4598,  0.6007,  0.6226],
#         [-0.1963, -0.1033, -0.0457, -0.2503, -0.1037, -0.1962, -0.2178, -0.0939],
#         [-0.1621,  0.2844,  0.5886,  0.2200,  0.0314,  0.2869, -0.1650,  0.3297]],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.6142,  0.5611,  0.6370,  0.6335,  0.5032,  0.4598,  0.6007,  0.6226],
#         [-0.1963, -0.1033, -0.0457, -0.2503, -0.1037, -0.1962, -0.2178, -0.0939],
#         [-0.1621,  0.2844,  0.5886,  0.2200,  0.0315,  0.2869, -0.1650,  0.3297]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[4.8879e-07, 1.6255e-06, 1.7894e-07, 3.3791e-08, 8.4197e-06, 1.3697e-06,
#          3.8619e-07, 4.6192e-07],
#         [1.6035e-06, 4.0635e-06, 4.5990e-07, 1.2658e-07, 1.9612e-05, 3.7636e-06,
#          1.3292e-06, 1.2062e-06],
#         [5.3948e-06, 2.6180e-05, 5.7554e-06, 1.1033e-06, 7.2661e-05, 2.4094e-05,
#          4.0124e-06, 8.7469e-06]], grad_fn=<TBackward0>)
# real y: tensor([ 0.6133, -0.2033, -0.1716,  0.5605, -0.1114,  0.2683,  0.6373, -0.0577,
#          0.5678,  0.6299, -0.2589,  0.2205,  0.5014, -0.1078,  0.0197,  0.4585,
#         -0.2023,  0.2755,  0.5990, -0.2286, -0.1767,  0.6213, -0.1012,  0.3188])
# Epoch: 400
# [Validation]	 J_a: 135.21
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 138.24
# Epoch: 401
# [Validation]	 J_a: 96.70
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE:
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 15.23
# Epoch: 893
# [Validation]	 J_a: 11.12
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 14.15
# Epoch: 894
# [Validation]	 J_a: 50.86
# [Validation]	 L: -3.0263
# [Validation]	 alpha * MSE: 53.89
# Epoch: 895
# [Validation]	 J_a: 13.42
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 16.44
# Epoch: 896
# [Validation]	 J_a: 54.48
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 57.51
# Epoch: 897
# [Validation]	 J_a: 14.37
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 17.40
# Epoch: 898
# [Validation]	 J_a: 16.86
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 19.88
# Epoch: 899
# [Validation]	 J_a: 59.63
# [Validation]	 L: -3.0249
# [Validation]	 alpha * MSE: 62.65
# Epoch: 900, ELBO now is -2.9843873977661133, regression loss is 0.0005386816337704659
# pred_y: tensor([[ 0.6209,  0.5560,  0.6940,  0.6013,  0.4296,  0.5901,  0.6141,  0.5917],
#         [-0.0577, -0.1076, -0.2368, -0.1091, -0.3125, -0.0544, -0.2251, -0.0472],
#         [ 0.0710,  0.1890,  0.2916,  0.0544,  0.0783,  0.0476,  0.0299,  0.0411]],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.6209,  0.5560,  0.6940,  0.6013,  0.4296,  0.5901,  0.6141,  0.5917],
#         [-0.0577, -0.1076, -0.2368, -0.1091, -0.3125, -0.0544, -0.2251, -0.0472],
#         [ 0.0710,  0.1890,  0.2916,  0.0544,  0.0783,  0.0476,  0.0299,  0.0411]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[9.8209e-07, 8.5330e-07, 1.9069e-09, 9.2488e-07, 4.3509e-09, 1.3599e-06,
#          9.4395e-08, 1.7499e-06],
#         [1.2322e-06, 1.2907e-06, 4.4801e-09, 1.3197e-06, 1.1694e-08, 1.6760e-06,
#          1.8520e-07, 2.1120e-06],
#         [5.4355e-06, 7.1437e-06, 5.3306e-08, 5.4569e-06, 9.8054e-08, 7.2614e-06,
#          8.2541e-07, 8.0244e-06]], grad_fn=<TBackward0>)
# real y: tensor([ 0.6198, -0.0548,  0.0647,  0.5550, -0.1071,  0.1866,  0.6933, -0.2330,
#          0.3088,  0.6005, -0.1078,  0.0523,  0.4295, -0.3104,  0.0894,  0.5891,
#         -0.0529,  0.0472,  0.6134, -0.2220,  0.0335,  0.5908, -0.0446,  0.0391])
# Epoch: 900
# [Validation]	 J_a: 18.87
# [Validation]	 L: -3.0249
# [Validation]	 alpha * MSE: 21.89
# Epoch: 901
# [Validation]	 J_a: 197.67
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 200.70
# Epoch: 902
# [Validation]	 J_a: 229.37
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 232.40
# Epoch: 903
# [Validation]	 J_a: 232.26
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 235.29
# Epoch: 904
# [Validation]	 J_a: 41.85
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 44.87
# Epoch: 905
# [Validation]	 J_a: 65.00
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 68.03
# Epoch: 906
# [Validation]	 J_a: 198.88
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 201.91
# Epoch: 907
# [Validation]	 J_a: 71.08
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 74.10
# Epoch: 908
# [Validation]	 J_a: 44.97
# [Validation]	 L: -3.0262
# [Validation]	 alpha * MSE: 47.99
# Epoch: 909
# [Validation]	 J_a: 43.66
# [Validation]	 L: -3.0254
# [Validation]	 alpha * MSE: 46.68
# Epoch: 910
# [Validation]	 J_a: 54.49
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE:
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 70.43
# Epoch: 982
# [Validation]	 J_a: 22.61
# [Validation]	 L: -3.0260
# [Validation]	 alpha * MSE: 25.64
# Epoch: 983
# [Validation]	 J_a: 183.75
# [Validation]	 L: -3.0256
# [Validation]	 alpha * MSE: 186.77
# Epoch: 984
# [Validation]	 J_a: 9.52
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 12.55
# Epoch: 985
# [Validation]	 J_a: 14.95
# [Validation]	 L: -3.0259
# [Validation]	 alpha * MSE: 17.98
# Epoch: 986
# [Validation]	 J_a: 35.37
# [Validation]	 L: -3.0261
# [Validation]	 alpha * MSE: 38.40
# Epoch: 987
# [Validation]	 J_a: 8.98
# [Validation]	 L: -3.0255
# [Validation]	 alpha * MSE: 12.01
# Epoch: 988
# [Validation]	 J_a: 10.00
# [Validation]	 L: -3.0250
# [Validation]	 alpha * MSE: 13.03
# Epoch: 989
# [Validation]	 J_a: 26.82
# [Validation]	 L: -3.0258
# [Validation]	 alpha * MSE: 29.84
# Epoch: 990
# [Validation]	 J_a: 43.11
# [Validation]	 L: -3.0257
# [Validation]	 alpha * MSE: 46.14

# %%
# Save the list  
torch.save([J_collect, L_collect, MSE_collect], './save/levelslopecur_JLMSElist_5000.pt')  
torch.save(model.state_dict(), "./save/model_levelslopecur_5000.pt")

# %%
# To load the list back  
J_collect, L_collect, MSE_collect = torch.load('./save/levelslopecur_JLMSElist_5000.pt')  
# test = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
model.load_state_dict(torch.load("./save/model_levelslopecur_5000.pt"))
model.eval()
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_37044\4209869423.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   J_collect, L_collect, MSE_collect = torch.load('./save/levelslopecur_JLMSElist_5000.pt')
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_37044\4209869423.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("./save/model_levelslopecur_5000.pt"))
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=787, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=35, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
#   (classifier): Classifier(
#     (dense): Linear(in_features=784, out_features=256, bias=True)
#     (logits): Linear(in_features=256, out_features=3, bias=True)
#   )
#   (regressor): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=3, bias=True)
#       (log_var): Linear(in_features=128, out_features=3, bias=True)
#     )
#   )
# )

# %%
# 创建子图
fig, axarr = plt.subplots(3, 1, figsize=(15, 10))  # 3 行 1 列子图

epochs = range(1, EPOCH) 

# 第一个子图: J_collect
axarr[0].plot(epochs[100:], J_collect[100:], label='J_collect', color='b', linestyle='-', linewidth=1.5)
# axarr[0].set_title('J_alpha')
axarr[0].set_xlabel('Epochs (100 to 5000)')
axarr[0].set_ylabel('J_alpha')
axarr[0].grid()

# 第二个子图: L_collect
axarr[1].plot(epochs[100:], L_collect[100:], label='L_collect', color='g', linestyle='-', linewidth=1.5)
# axarr[1].set_title('L')
axarr[1].set_xlabel('Epochs (100 to 5000)')
axarr[1].set_ylabel('L')
axarr[1].grid()

# 第三个子图: MSE_collect
axarr[2].plot(epochs[100:], np.log(MSE_collect[100:]), label='log(MSE_collect)', color='r', linestyle='-', linewidth=1.5)
# axarr[2].set_title('MSE_collect')
axarr[2].set_xlabel('Epochs (100 to 5000)')
axarr[2].set_ylabel('Log(alpha * MSE)')
axarr[2].grid()

for i in range(3):
    axarr[i].set_xlim(100, 5050)

fig.suptitle("Loss value over epochs (Curvature)", fontsize=16)

# 调整子图布局
plt.tight_layout()

# 显示图像
plt.show()

# %% [markdown]
# ## Conditional generation
#
# When the model is done training you can generate samples conditionally given some normal distributed noise $z$ and a label $y$.
#
# *The model below has only trained for 10 iterations, so the perfomance is not representative*.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import torch
from torch.autograd import Variable

# Initialize figure and 2x5 axes array
fig, axarr = plt.subplots(3, 10, figsize=(50, 15), subplot_kw={'projection': '3d'})

# Set the range for T and K
T = np.linspace(0.1, 0.6, 28)
K = np.linspace(0.7, 1.3, 28)
K, T = np.meshgrid(K, T)

z = Variable(torch.randn(1, z_dim))
if cuda:
    z = z.cuda(device=0)

model.eval()
for dim in range(3):  # Loop over each dimension of the 3D y
    # level_min, level_max = level.min().item(), level.max().item()
    y_min = tar[:, dim].min()
    y_max = tar[:, dim].max()
    y_values = np.linspace(y_min, y_max, 10)
    for i, y_value in enumerate(y_values):
        # Set y to a specific value for the current dimension, keep others fixed
        y = Variable(torch.zeros(1, 3))  # Initialize y as a 3D tensor
        y[:, 0] = tar[:, 0].mean()
        y[:, 1] = tar[:, 1].mean()
        y[:, 2] = tar[:, 2].mean()
        # y[:, 2] = tar[:, 2].mean()
        y[:, dim] = y_value  # Set only the current dimension to y_value
        if cuda:
            y = y.cuda(device=0)

        # Generate samples from the model
        x_mu = model.sample(z, y)

        samples = x_mu.data.view(-1, 1, 28, 28).cpu().numpy()

        # Determine subplot position (row, column)
        row = dim  # Row for the specific y dimension
        col = i    # Column for the y_value within that dimension
        ax = axarr[row, col]

        # Plot the surface
        surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')

        # Set title and adjust z-axis limits for consistency
        # ax.set_title(f'y_dim {dim+1} value = {y_value:.2f}')

        ax.set_title(f'''generate y in dim {dim+1}: {y_value}\n 
                regress y: {model.regress(x_mu)[0][0][dim]}\n
                y_mu: {model.regress(x_mu)[1][0][dim]}\n    
                y_std: {model.regress(x_mu)[2].mul(0.5).exp_()[0][dim]}''',
                linespacing=0.4, fontsize=16)
        
        ax.set_zlim(0, 1)  # Adjust the z-axis limits to be consistent across all plots

# Show the final figure with all subplots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 30
#      28 y[:, 0] = tar[:, 0].mean()
#      29 y[:, 1] = tar[:, 1].mean()
# ---> 30 y[:, 2] = tar[:, 2].mean()
#      31 # y[:, 2] = tar[:, 2].mean()
#      32 y[:, dim] = y_value  # Set only the current dimension to y_value
#
# IndexError: index 2 is out of bounds for dimension 1 with size 2

# %%
stop!
# Out:
#   Cell In[14], line 1
#     stop!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Stacked Deep Generative Model
#
# The M1+M2 model also described in the same paper is an M1 model (VAE) with an M2 model stacked on top of it. That means that we train the a VAE end-to-end on the data given dataset, then we use the learned encoder as a feature extractor and feed the data transformed by the M1 encoder into the M2 model.
#
# We approach is somewhat similar to restricted boltzmann machines (RBMs) in the sense that we perform a layerwise training of the whole model by first training a level-1 feature extractor and stacking another model on top of this. The stacked model is therefore also more modular, but cannot be trained end-to-end, which is a downside.

# %%
from models import VariationalAutoencoder, StackedDeepGenerativeModel

features = VariationalAutoencoder([784, z_dim, h_dim])
model = StackedDeepGenerativeModel([784, y_dim, z_dim, h_dim], features)

# %% [markdown]
# Typically, you would want to load a pretrained feature extractor VAE instead.

# %%
features = torch.load("./your-pretrained-vae.pt")
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_15576\1198095296.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   features = torch.load("./your-pretrained-vae.pt")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 features = torch.load("./your-pretrained-vae.pt")
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './your-pretrained-vae.pt'

# %%
from torch.autograd import Variable

for epoch in range(10):
    model.train()
    total_loss, accuracy = (0, 0)
    for (x, y), (u, _) in zip(cycle(labelled), unlabelled):
        # Wrap in variables
        x, y, u = Variable(x), Variable(y), Variable(u)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            u = u.cuda(device=0)

        L = -elbo(x, y)
        U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        logits = model.classify(x)
        
        # Regular cross entropy
        classication_loss = torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

        J_alpha = L - alpha * classication_loss + U

        J_alpha.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.data[0]
        accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
        
    if epoch % 1 == 0:
        model.eval()
        m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, accuracy = (0, 0)
        for x, y in validation:
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            U = -elbo(x)

            logits = model.classify(x)
            classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

            J_alpha = L + alpha * classication_loss + U

            total_loss += J_alpha.data[0]

            _, pred_idx = torch.max(logits, 1)
            _, lab_idx = torch.max(y, 1)
            accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

        m = len(validation)
        print("[Validation]\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

# %% [markdown]
# ## Additional tips
#
# You can change the built-in classifier with your own, for example if you want a CNN as a classifier you can do the following.

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvolutionalClassifier(nn.Module):
    def __init__(self):
        super(ConvolutionalClassifier, self).__init__()        
        self.conv1 = nn.Conv2d(1, 64, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=3)
        self.pool = nn.MaxPool2d(kernel_size=4)

        size = int((28 - 3) + 1)//4
        size = int((size - 3) + 1)//4
                
        self.fc1 = nn.Linear(32*size**2, 50)
        self.fc2 = nn.Linear(50, 10)
        
    def forward(self, x):
        batch, *_ = x.size()
        x = x.view(-1, 1, 28, 28)
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(x.view(batch, -1))
        x = self.fc1(x)
        x = self.fc2(x)
        return F.softmax(x, dim=-1)

classifier = ConvolutionalClassifier()
model.classifier = classifier

# %%
model
# Out:
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=794, out_features=256)
#       (1): Linear(in_features=256, out_features=128)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32)
#       (log_var): Linear(in_features=128, out_features=32)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=42, out_features=128)
#       (1): Linear(in_features=128, out_features=256)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784)
#     (output_activation): Sigmoid()
#   )
#   (classifier): ConvolutionalClassifier(
#     (conv1): Conv2d (1, 64, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d (64, 32, kernel_size=(3, 3), stride=(1, 1))
#     (pool): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), dilation=(1, 1))
#     (fc1): Linear(in_features=32, out_features=50)
#     (fc2): Linear(in_features=50, out_features=10)
#   )
# )
