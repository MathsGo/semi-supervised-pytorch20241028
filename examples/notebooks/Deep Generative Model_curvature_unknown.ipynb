# %%
# Imports
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import random_split
import torchvision.transforms as transforms
import torch.nn.functional as F

cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.io
import sys
sys.path.append("../../semi-supervised")

# %% [markdown]
# # Deep Generative Model
#
# In this notebook we show how you can use the deep "generative model for semi-supervised learning" as presented in [[Kingma 2014]](https://arxiv.org/abs/1406.5298). The paper posits three different models, though we are just interested in two of these: the M2 model and the M1+M2 model.
#
# The M1 model is just a variational autoencoder, so we refer to the previous notebook for more information on this. The M2 model however is an extension to the VAE to include label information for a semi-supervised objective. The structure is shown below (left: inference model, right: generative model).
#
# <img src="../images/dgm.png" width="400px"/>
#
# The point of the generative model is to seperate the partially observed label information $y$ from the latent variable $z$ in order to learn a representation that seperates these two variables. We can use this model for semi-supervised learning as the inference model must also infer the label from the data $x$ along with the latent variable $z$.

# %%
from models import DeepGenerativeModel, StackedDeepGenerativeModel

y_dim = 1
z_dim = 32
h_dim = [256, 128]

model = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
model
# Out:
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\vae.py:114: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# c:\Users\jwang47\OneDrive - Delft University of Technology\Generate_Volatility_Surface\Code\semi-supervised-pytorch20241028\examples\notebooks\../../semi-supervised\models\dgm.py:67: FutureWarning: `nn.init.xavier_normal` is now deprecated in favor of `nn.init.xavier_normal_`.
#   init.xavier_normal(m.weight.data)
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=785, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=33, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
#   (classifier): Classifier(
#     (dense): Linear(in_features=784, out_features=256, bias=True)
#     (logits): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (regressor): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=1, bias=True)
#       (log_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
print(model.encoder.hidden[0])
print(model.decoder.hidden[0])
# Out:
# Linear(in_features=785, out_features=256, bias=True)
# Linear(in_features=33, out_features=128, bias=True)

# %% [markdown]
# Notice how theres now a classifier associated with model. This classifier will just be a simple model that takes the size of the first layer encoder network. We also have a larger input space on both the encoder and decoder to make room for label information, in this case 10 labels.

# %% [markdown]
# ## Training
#
# Recall the ELBO from the VAE formulation, we want to construct a similar ELBO when we include labelled data $y$. In the case that we have labels, the ELBO has a simple formulation that is similar to the one for the VAE. The difference here is that we must also have a prior over labels $p(y)$, which we choose to be uniform over the different classes.
#
# \begin{align}
# \log p(x, y) &= \log \int q(z|x, y) \frac{p(x, y, z)}{q(z|xy)} \ dz \geq \int q(z|x, y) \log \frac{p(x, y, z)}{q(z|xy)} \ dz\\
# &= \int q(z|x, y) [ \log p(x|z,y) + \log p(y) ] \ dz + \int q(z|x, y) \log \frac{p(z)}{q(z|xy)} \ dz\\
# &= \mathbb{E}_{q(z|x, y)} [ \log p(x|z,y) + \log p(y) ] - KL(p(z)||q(z|xy)) = - \mathcal{L}(x, y)
# \end{align}
#
# In the case when the labels are not observed, we can instead integrate over all of the labels to achieve the same effect.
#
# \begin{align}
# \log p(x) &= \log \sum_{y} \int q(z,y|x) \frac{p(x, y, z)}{q(z,y|x)} \ dz \geq \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz\\
# &= \sum_{y} q(y|x) \int q(z|x, y) \log \frac{p(x, y, z)}{q(z,y|x)} \ dz + \sum_{y} q(y|x) \log q(y|x) \int q(z|x, y) \ dz\\
# &= \sum_{y} q(y|x) (- \mathcal{L}(x,y)) + \mathcal{H}(q(y|x)) = - \mathcal{U}(x)
# \end{align}
#
# Notice how in both cases we need to compute the labelled bound, but in the unlabelled case we need to do it $n$ times where $n$ is the number of classes. In this model, we do not learn directly from the labelled class, as there is no cross entropy term between $y$ and our model output $q(y|x)$. We therefore add an auxiliary loss to arrive at the final loss objective.
#
# $$\mathcal{J}^{\alpha} = \sum_{(x_l, y_l)}\mathcal{L}(x_l, y_l) + \alpha \cdot \mathbb{E}_{x_l, y_l}[- \log q(y_l|x_l)] + \sum_{(x_u)}\mathcal{U}(x_u)$$
#
# Where $l, u$ denotes labelled and unlabelled data respectively and $\alpha$ is a hyperparameter that denotes the reliance of labelled data.

# %%
# from datautils import get_mnist

# # Only use 10 labelled examples per class
# # The rest of the data is unlabelled.
# labelled, unlabelled, validation = get_mnist(location="./", batch_size=64, labels_per_class=10)
# alpha = 0.1 * len(unlabelled) / len(labelled)


# def binary_cross_entropy(r, x):
#     return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999))

# %% [markdown]
# # Load Data

# %%
data = scipy.io.loadmat('./data/heston_vol_images_train_30000.mat')
impliedVolsurfaces = torch.tensor(data['impliedVolsurfaces_collection']).float()

max_val = torch.max(impliedVolsurfaces)
min_val = torch.min(impliedVolsurfaces)

impliedVolsurfaces_normalized = (impliedVolsurfaces - min_val) / (max_val - min_val)

impliedVolsurfaces_normalized_flatten = impliedVolsurfaces_normalized.reshape(30000, 784)

lhs_matrix = data["lhs_matrix"]  # 形状: [30000, 6]

# 获取公式中的变量
rho = lhs_matrix[:, 0]       # 第 1 列，rho
v0 = lhs_matrix[:, 2]        # 第 3 列，v0
gamma = lhs_matrix[:, 3]     # 第 4 列，gamma

# 计算公式
cur_0 = torch.from_numpy((gamma**2) / (24 * v0**(3/2)) * (2 - 5 * rho**2)).type(torch.float32)

# slope = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=1, axis=2)) * 1000
# # K_index_s = slope.shape[2] // 2
# # slope = torch.from_numpy(slope[:, :, K_index_s, :])
# slope_ave = torch.mean(slope, dim=[2, 3]).squeeze(1)
# print("slope:", slope_ave.shape, slope_ave.min(), slope_ave.max())

# curvature = torch.from_numpy(np.diff(impliedVolsurfaces_normalized, n=2, axis=2)) * 1000
# # K_index_c = curvature.shape[2] // 2
# # curvature = torch.from_numpy(curvature[:, :, K_index_c, :])
# # curvature_ave = torch.max(curvature, dim=[2, 3]).squeeze(1)
# values, indices = curvature.reshape(30000, -1).sort()
# curvature_l3 = values[:, -3]
# # print("curvature:", curvature_ave.shape, curvature.min(), curvature.max())
# print("curvature:", curvature_l3.shape, curvature_l3.min(), curvature_l3.max())

tar = cur_0

# # tar = torch.stack([level, slope_ave, curvature_l3], dim=1)
# # print(tar.shape)

ivs = TensorDataset(impliedVolsurfaces_normalized_flatten, tar)

torch.manual_seed(0)

total_size = len(ivs)
train_size = int(total_size * 0.7)
labelled_size = int(train_size * 1)
# labelled_size = int(train_size * 0.1)
# labelled_size = int(0)
# unlabelled_size = train_size - labelled_size
validation_size = total_size - train_size
alpha = 0.1 * train_size


# labelled_dataset, unlabelled_dataset, validation_dataset = random_split(ivs, [labelled_size, unlabelled_size, validation_size])
labelled_dataset, validation_dataset = random_split(ivs, [labelled_size,  validation_size])

BATCH_SIZE = 64
EPOCH = 5001

labelled = DataLoader(labelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
# unlabelled = DataLoader(unlabelled_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# import torch
# import numpy as np

# # 模拟生成 z 的数据（3000 张 28x28 的 torch tensor surface）
# z = impliedVolsurfaces_normalized.squeeze(1)

# # K 和 T 的 linspace
# K = np.linspace(0.7, 1.3, 28)
# T = np.linspace(0.1, 0.6, 28)
# dK = K[1] - K[0]  # K 的步长

# # 定义计算曲率的函数
# def calculate_curvature(surface):
#     """
#     计算一张 surface 沿 K 方向的平均曲率
#     """
#     # 转为 numpy 数组以方便处理
#     surface_np = surface.numpy()

#     # 沿着 K 方向计算二阶导数 (曲率)
#     # 采用有限差分： f''(K) ≈ (f(K+1) - 2*f(K) + f(K-1)) / dK^2
#     curvature = (surface_np[2:, :] - 2 * surface_np[1:-1, :] + surface_np[:-2, :]) / dK**2

#     # 返回整张 surface 的平均曲率
#     return curvature.mean()

# # 对所有 surfaces 计算平均曲率
# average_curvatures = torch.tensor([calculate_curvature(surface) for surface in z])

# # 给出示例
# example_surface_index = 0
# example_surface = z[example_surface_index]
# example_average_curvature = calculate_curvature(example_surface)

# print(f"Example Surface Index: {example_surface_index}")
# print(f"Example Average Curvature: {example_average_curvature}")
# print(f"All Average Curvatures Shape: {average_curvatures.shape}")
# average_curvatures.min(), average_curvatures.max()

# %%
# # level min max
# from mpl_toolkits.mplot3d import Axes3D

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[level.argmin()].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[level.argmax()].view(28, 28), cmap='viridis')

# %%
# # slope min max
# from mpl_toolkits.mplot3d import Axes3D

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmin()].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[slope_ave.argmax()].view(28, 28), cmap='viridis')

# %%
# # curvature min max
# from mpl_toolkits.mplot3d import Axes3D

# sorted, indices = curvature_l3.sort()
# print(sorted)
# print(indices)

# i = 1

# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# K, T = np.meshgrid(K, T)
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[-i]].view(28, 28), cmap='viridis')
# ax.plot_surface(K, T, impliedVolsurfaces_normalized[indices[i]].view(28, 28), cmap='viridis')

# %%
from itertools import cycle
from inference import SVI, ImportanceWeightedSampler

# You can use importance weighted samples [Burda, 2015] to get a better estimate
# on the log-likelihood.
sampler = ImportanceWeightedSampler(mc=1, iw=1)

if cuda: model = model.cuda()
elbo = SVI(model, likelihood=F.mse_loss, sampler=sampler)

# %% [markdown]
# The library is conventially packed with the `SVI` method that does all of the work of calculating the lower bound for both labelled and unlabelled data depending on whether the label is given. It also manages to perform the enumeration of all the labels.
#
# Remember that the labels have to be in a *one-hot encoded* format in order to work with SVI.

# %%
from torch.autograd import Variable

J_collect = []
L_collect = []
MSE_collect = []

for epoch in range(1, EPOCH):
    model.train()
    total_loss, L_sum, MSE_sum = (0, 0, 0)
    for x, y in labelled:
        # Wrap in variables
        # x, y, u = Variable(x), Variable(y), Variable(u)
        # y = y.unsqueeze(1)
        x, y = Variable(x), Variable(y)
        # print(x, y)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            # u = u.cuda(device=0)

        L = -elbo(x, y)
        # U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        pred_y, y_mu, y_logvar = model.regress(x)
        # print(pred_y.shape)
        pred_y = pred_y.squeeze(1)
        # print(pred_y.shape)
        # print(pred_y.sum())
        
        # Regular cross entropy
        # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
        # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
        regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()

        J_alpha = L + alpha * regression_loss

        J_alpha.backward()
        # L.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.item()
        # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
    if epoch % 100 == 0:
        print("Epoch: {}, ELBO now is {}, regression loss is {}".format(epoch, L, regression_loss))
        print("pred_y:", pred_y.t())
        print("y_mu:", y_mu.t())
        print("y_std:", y_logvar.mul(0.5).exp_().t())
        print('real y:', y.view(-1))
        
    if epoch % 1 == 0:
        model.eval()
        # m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        # print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, L_sum, MSE_sum = (0, 0, 0)
        for x, y in validation:
            # y = y.unsqueeze(1)
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            # U = -elbo(x)

            # logits = model.classify(x)
            pred_y, y_mu, y_logvar = model.regress(x)

            # classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()
            # regression_loss = -torch.sum(0.5 + 0.5 * torch.log(2 * np.pi * torch.exp(pred_y_log_var))).mean()
            # regression_loss = torch.mean(-0.5+0.5*(torch.div((pred_y-y).pow(2), pred_y_log_var.exp()) + pred_y_log_var))
            # print(pred_y.shape)
            pred_y = pred_y.squeeze(1)
            # print(pred_y.shape)
            regression_loss = F.mse_loss(pred_y, y, reduction='sum').mean()
            J_alpha = L + alpha * regression_loss



            total_loss += J_alpha.item()
            L_sum += L.item()
            MSE_sum += regression_loss.item()

            # print(J_alpha.item())
            # print(L.item())
            # print(alpha * regression_loss.item())

            # _, pred_idx = torch.max(logits, 1)
            # _, lab_idx = torch.max(y, 1)
            # accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

    
        m = len(validation)
        print("[Validation]\t J_a: {:.2f}".format(total_loss / m))
        print("[Validation]\t L: {:.4f}".format(L_sum / m)) # !didn't sum over L, need to be changed
        print("[Validation]\t alpha * MSE: {:.2f}".format(alpha * MSE_sum / m)) # !didn't sum over regression_loss, need to be changed

        J_collect.append(total_loss / m)
        L_collect.append(L_sum / m)
        MSE_collect.append(MSE_sum / m)
        # print("[Validation]\t L: {:.2f}".format(total_loss / m))
# Out:
# Epoch: 1
# [Validation]	 J_a: 6747.38
# [Validation]	 L: -63.4312
# [Validation]	 alpha * MSE: 6810.81
# Epoch: 2
# [Validation]	 J_a: 7243.41
# [Validation]	 L: -63.4315
# [Validation]	 alpha * MSE: 7306.84
# Epoch: 3
# [Validation]	 J_a: 4709.10
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 4772.53
# Epoch: 4
# [Validation]	 J_a: 2925.11
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 2988.54
# Epoch: 5
# [Validation]	 J_a: 724.00
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 787.44
# Epoch: 6
# [Validation]	 J_a: 1053.63
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 1117.06
# Epoch: 7
# [Validation]	 J_a: 14391.43
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 14454.86
# Epoch: 8
# [Validation]	 J_a: 1769.47
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 1832.90
# Epoch: 9
# [Validation]	 J_a: 510.57
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 574.00
# Epoch: 10
# [Validation]	 J_a: 658.89
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 722.33
# Epoch: 11
# [Validation]	 J_a: 295.87
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 359.30
# Epoch: 12
# [Validation]	 J_a: 273.82
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 337.25
# Epoch: 13
# [Validation]	 J_a: 1499.07
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 1562.51
# Epoch: 14
# [Validation]	 J_a: 647.02
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 710.45
# Epoch: 15
# [Validation]	 J_a: 610.85
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 674.28
# Epoch: 16
# [Validation]	 J_a: 1552.62
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 1616.05
# Epoch: 17
# [Validation]	 J_a: 176.60
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 240.04
# Epoch: 18
# [Validation]	 J_a: 1425.45
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 1488.88
# Epoch: 19
# [Validation]	 J_a: 436.99
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 500.42
# Epoch: 20
# [Validation]	 J_a: 1094.34
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 1157.78
# Epoch: 21
# [Validation]	 J_a: 278.33
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 341.76
# Epoch: 22
# [Validation]	 J_a: 150.55
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 213.98
# Epoch: 23
# [Validation]	 J_a: 260.73
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 324.17
# Epoch: 24
# [Validation]	 J_a: 823.56
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 886.99
# Epoch: 25
# [Validation]	 J_a: 201.49
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 264.92
# Epoch: 26
# [Validation]	 J_a: 563.26
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 626.69
# Epoch: 27
# [Validation]	 J_a: 111.38
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 174.81
# Epoch: 28
# [Validation]	 J_a: 1469.15
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 1532.59
# Epoch: 29
# [Validation]	 J_a: 179.57
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 243.00
# Epoch: 30
# [Validation]	 J_a: 433.67
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 497.10
# Epoch: 31
# [Validation]	 J_a: 153.87
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 217.30
# Epoch: 32
# [Validation]	 J_a: 267.67
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 331.10
# Epoch: 33
# [Validation]	 J_a: 147.59
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 211.02
# Epoch: 34
# [Validation]	 J_a: 673.41
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 736.85
# Epoch: 35
# [Validation]	 J_a: 64.63
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 128.07
# Epoch: 36
# [Validation]	 J_a: 348.64
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 412.08
# Epoch: 37
# [Validation]	 J_a: 502.26
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 565.69
# Epoch: 38
# [Validation]	 J_a: 325.77
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 389.20
# Epoch: 39
# [Validation]	 J_a: 115.46
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 178.89
# Epoch: 40
# [Validation]	 J_a: 262.56
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 325.99
# Epoch: 41
# [Validation]	 J_a: 52.54
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 115.98
# Epoch: 42
# [Validation]	 J_a: 499.17
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 562.61
# Epoch: 43
# [Validation]	 J_a: 98.57
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 162.00
# Epoch: 44
# [Validation]	 J_a: 163.34
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 226.78
# Epoch: 45
# [Validation]	 J_a: 1710.58
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 1774.02
# Epoch: 46
# [Validation]	 J_a: 261.55
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 324.99
# Epoch: 47
# [Validation]	 J_a: 44.64
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 108.07
# Epoch: 48
# [Validation]	 J_a: 49.79
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 113.23
# Epoch: 49
# [Validation]	 J_a: 53.81
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 117.25
# Epoch: 50
# [Validation]	 J_a: 355.47
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 418.90
# Epoch: 51
# [Validation]	 J_a: 46.93
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 110.37
# Epoch: 52
# [Validation]	 J_a: 330.79
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 394.22
# Epoch: 53
# [Validation]	 J_a: 749.12
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 812.55
# Epoch: 54
# [Validation]	 J_a: 81.11
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 144.55
# Epoch: 55
# [Validation]	 J_a: 103.35
# [Validation]	 L: -63.4320
# [Validation]	 alpha * MSE: 166.79
# Epoch: 56
# [Validation]	 J_a: 24.45
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 87.88
# Epoch: 57
# [Validation]	 J_a: 133.47
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 196.90
# Epoch: 58
# [Validation]	 J_a: 104.28
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 167.71
# Epoch: 59
# [Validation]	 J_a: 74.20
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 137.63
# Epoch: 60
# [Validation]	 J_a: 273.96
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 337.39
# Epoch: 61
# [Validation]	 J_a: 145.10
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 208.53
# Epoch: 62
# [Validation]	 J_a: 14.73
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 78.17
# Epoch: 63
# [Validation]	 J_a: 318.70
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 382.14
# Epoch: 64
# [Validation]	 J_a: 187.22
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 250.65
# Epoch: 65
# [Validation]	 J_a: 194.39
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 257.82
# Epoch: 66
# [Validation]	 J_a: 1951.69
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 2015.12
# Epoch: 67
# [Validation]	 J_a: 64.52
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 127.96
# Epoch: 68
# [Validation]	 J_a: 249.44
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 312.87
# Epoch: 69
# [Validation]	 J_a: 182.26
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 245.69
# Epoch: 70
# [Validation]	 J_a: 59.27
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 122.71
# Epoch: 71
# [Validation]	 J_a: 70.89
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 134.32
# Epoch: 72
# [Validation]	 J_a: 139.75
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 203.18
# Epoch: 73
# [Validation]	 J_a: 280.34
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 343.77
# Epoch: 74
# [Validation]	 J_a: 559.83
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 623.26
# Epoch: 75
# [Validation]	 J_a: 38.44
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 101.88
# Epoch: 76
# [Validation]	 J_a: 196.35
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 259.78
# Epoch: 77
# [Validation]	 J_a: 42.69
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 106.13
# Epoch: 78
# [Validation]	 J_a: 25.45
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 88.89
# Epoch: 79
# [Validation]	 J_a: 271.38
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 334.81
# Epoch: 80
# [Validation]	 J_a: 338.14
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 401.57
# Epoch: 81
# [Validation]	 J_a: 335.12
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 398.55
# Epoch: 82
# [Validation]	 J_a: 60.10
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 123.54
# Epoch: 83
# [Validation]	 J_a: 206.55
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 269.98
# Epoch: 84
# [Validation]	 J_a: 28.80
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 92.24
# Epoch: 85
# [Validation]	 J_a: 148.19
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 211.63
# Epoch: 86
# [Validation]	 J_a: 210.27
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 273.70
# Epoch: 87
# [Validation]	 J_a: 1.05
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 64.49
# Epoch: 88
# [Validation]	 J_a: 55.65
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 119.08
# Epoch: 89
# [Validation]	 J_a: 33.06
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 96.49
# Epoch: 90
# [Validation]	 J_a: 19.60
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 83.03
# Epoch: 91
# [Validation]	 J_a: 52.70
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 116.14
# Epoch: 92
# [Validation]	 J_a: 12.31
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 75.74
# Epoch: 93
# [Validation]	 J_a: 711.90
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 775.33
# Epoch: 94
# [Validation]	 J_a: 331.18
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 394.62
# Epoch: 95
# [Validation]	 J_a: 179.40
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 242.84
# Epoch: 96
# [Validation]	 J_a: 278.31
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 341.74
# Epoch: 97
# [Validation]	 J_a: 64.08
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 127.51
# Epoch: 98
# [Validation]	 J_a: 1315.70
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 1379.13
# Epoch: 99
# [Validation]	 J_a: 75.35
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 138.78
# Epoch: 100, ELBO now is -7.457225799560547, regression loss is 0.0015804030699655414
# pred_y: tensor([ 0.3813,  0.0556,  0.1814, -0.1946,  0.0026, -0.0806, -0.0709, -0.1232],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.3813,  0.0554,  0.1815, -0.1946,  0.0024, -0.0805, -0.0709, -0.1230]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[9.1446e-05, 1.1198e-04, 3.7880e-04, 3.9813e-05, 6.6757e-04, 1.4163e-04,
#          4.1542e-05, 2.8573e-04]], grad_fn=<TBackward0>)
# real y: tensor([ 0.3930,  0.0691,  0.1873, -0.1702,  0.0110, -0.0862, -0.0620, -0.1020])
# Epoch: 100
# [Validation]	 J_a: 277.21
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 340.65
# Epoch: 101
# [Validation]	 J_a: 11.54
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 74.97
# Epoch: 102
# [Validation]	 J_a: 15.96
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 79.39
# Epoch: 103
# [Validation]	 J_a: 87.65
# [Validation]	 L: -63.4321
# [Validation]	 alpha * MSE: 151.08
# Epoch: 104
# [Validation]	 J_a: 9.02
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 72.45
# Epoch: 105
# [Validation]	 J_a: 26.46
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 89.89
# Epoch: 106
# [Validation]	 J_a: 195.09
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 258.52
# Epoch: 107
# [Validation]	 J_a: 50.92
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 114.35
# Epoch: 108
# [Validation]	 J_a: 576.13
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 639.56
# Epoch: 109
# [Validation]	 J_a: 21.68
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 85.11
# Epoch: 110
# [Validation]	 J_a: 139.35
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 202.78
# Epoch: 111
# [Validation]	 J_a: 182.15
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 245.58
# Epoch: 112
# [Validation]	 J_a: 23.30
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 86.73
# Epoch: 113
# [Validation]	 J_a: 64.50
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 127.93
# Epoch: 114
# [Validation]	 J_a: 45.76
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 109.19
# Epoch: 115
# [Validation]	 J_a: 54.98
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 118.41
# Epoch: 116
# [Validation]	 J_a: 1.73
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 65.16
# Epoch: 117
# [Validation]	 J_a: 20.30
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 83.73
# Epoch: 118
# [Validation]	 J_a: 32.46
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 95.89
# Epoch: 119
# [Validation]	 J_a: 101.49
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 164.92
# Epoch: 120
# [Validation]	 J_a: 31.53
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 94.96
# Epoch: 121
# [Validation]	 J_a: 88.66
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 152.09
# Epoch: 122
# [Validation]	 J_a: 86.89
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 150.32
# Epoch: 123
# [Validation]	 J_a: 812.66
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 876.10
# Epoch: 124
# [Validation]	 J_a: 50.87
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 114.30
# Epoch: 125
# [Validation]	 J_a: 70.92
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 134.35
# Epoch: 126
# [Validation]	 J_a: 11.12
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 74.56
# Epoch: 127
# [Validation]	 J_a: 66.86
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 130.29
# Epoch: 128
# [Validation]	 J_a: 66.03
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 129.46
# Epoch: 129
# [Validation]	 J_a: 74.39
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 137.82
# Epoch: 130
# [Validation]	 J_a: 55.70
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 119.13
# Epoch: 131
# [Validation]	 J_a: 93.65
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 157.08
# Epoch: 132
# [Validation]	 J_a: 3.08
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 66.51
# Epoch: 133
# [Validation]	 J_a: 37.30
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 100.74
# Epoch: 134
# [Validation]	 J_a: 43.78
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 107.21
# Epoch: 135
# [Validation]	 J_a: 28.12
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 91.56
# Epoch: 136
# [Validation]	 J_a: 18.41
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 81.84
# Epoch: 137
# [Validation]	 J_a: 214.22
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 277.66
# Epoch: 138
# [Validation]	 J_a: 72.62
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 136.05
# Epoch: 139
# [Validation]	 J_a: 106.46
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 169.90
# Epoch: 140
# [Validation]	 J_a: 68.69
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 132.13
# Epoch: 141
# [Validation]	 J_a: 197.76
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 261.19
# Epoch: 142
# [Validation]	 J_a: 591.07
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 654.51
# Epoch: 143
# [Validation]	 J_a: 6.60
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 70.03
# Epoch: 144
# [Validation]	 J_a: 13.08
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 76.51
# Epoch: 145
# [Validation]	 J_a: 5.43
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 68.86
# Epoch: 146
# [Validation]	 J_a: 21.36
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 84.79
# Epoch: 147
# [Validation]	 J_a: -0.31
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 63.13
# Epoch: 148
# [Validation]	 J_a: 259.28
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 322.72
# Epoch: 149
# [Validation]	 J_a: -0.45
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 62.98
# Epoch: 150
# [Validation]	 J_a: 10.80
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 74.24
# Epoch: 151
# [Validation]	 J_a: 43.01
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 106.45
# Epoch: 152
# [Validation]	 J_a: -12.70
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 50.74
# Epoch: 153
# [Validation]	 J_a: 48.69
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 112.13
# Epoch: 154
# [Validation]	 J_a: 224.52
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 287.96
# Epoch: 155
# [Validation]	 J_a: 5.03
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 68.46
# Epoch: 156
# [Validation]	 J_a: 132.50
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 195.93
# Epoch: 157
# [Validation]	 J_a: 116.71
# [Validation]	 L: -63.4339
# [Validation]	 alpha * MSE: 180.14
# Epoch: 158
# [Validation]	 J_a: 53.39
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 116.83
# Epoch: 159
# [Validation]	 J_a: -8.95
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 54.49
# Epoch: 160
# [Validation]	 J_a: -17.74
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 45.69
# Epoch: 161
# [Validation]	 J_a: 36.20
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 99.63
# Epoch: 162
# [Validation]	 J_a: 16.18
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 79.61
# Epoch: 163
# [Validation]	 J_a: 350.69
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 414.12
# Epoch: 164
# [Validation]	 J_a: 42.32
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 105.76
# Epoch: 165
# [Validation]	 J_a: 242.00
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 305.44
# Epoch: 166
# [Validation]	 J_a: 89.77
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 153.20
# Epoch: 167
# [Validation]	 J_a: 18.52
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 81.96
# Epoch: 168
# [Validation]	 J_a: 262.28
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 325.72
# Epoch: 169
# [Validation]	 J_a: 21.17
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 84.60
# Epoch: 170
# [Validation]	 J_a: -12.41
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 51.02
# Epoch: 171
# [Validation]	 J_a: 25.29
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 88.73
# Epoch: 172
# [Validation]	 J_a: 173.82
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 237.25
# Epoch: 173
# [Validation]	 J_a: 221.86
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 285.29
# Epoch: 174
# [Validation]	 J_a: 77.16
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 140.60
# Epoch: 175
# [Validation]	 J_a: 13.49
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 76.93
# Epoch: 176
# [Validation]	 J_a: -4.86
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 58.58
# Epoch: 177
# [Validation]	 J_a: 7.46
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 70.89
# Epoch: 178
# [Validation]	 J_a: 294.08
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 357.52
# Epoch: 179
# [Validation]	 J_a: -15.72
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 47.71
# Epoch: 180
# [Validation]	 J_a: 173.95
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 237.38
# Epoch: 181
# [Validation]	 J_a: 0.54
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 63.97
# Epoch: 182
# [Validation]	 J_a: -7.18
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 56.26
# Epoch: 183
# [Validation]	 J_a: 204.35
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 267.79
# Epoch: 184
# [Validation]	 J_a: 59.96
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 123.40
# Epoch: 185
# [Validation]	 J_a: 216.81
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 280.25
# Epoch: 186
# [Validation]	 J_a: 319.14
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 382.57
# Epoch: 187
# [Validation]	 J_a: -14.65
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 48.78
# Epoch: 188
# [Validation]	 J_a: 3.15
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 66.58
# Epoch: 189
# [Validation]	 J_a: 125.69
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 189.12
# Epoch: 190
# [Validation]	 J_a: 2.16
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 65.59
# Epoch: 191
# [Validation]	 J_a: -6.20
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 57.23
# Epoch: 192
# [Validation]	 J_a: 35.28
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 98.71
# Epoch: 193
# [Validation]	 J_a: 191.38
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 254.82
# Epoch: 194
# [Validation]	 J_a: -14.58
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 48.85
# Epoch: 195
# [Validation]	 J_a: 272.97
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 336.40
# Epoch: 196
# [Validation]	 J_a: 128.12
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 191.56
# Epoch: 197
# [Validation]	 J_a: 76.76
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 140.19
# Epoch: 198
# [Validation]	 J_a: 22.12
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 85.56
# Epoch: 199
# [Validation]	 J_a: 111.42
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 174.85
# Epoch: 200, ELBO now is -8.194794654846191, regression loss is 0.0016826807986944914
# pred_y: tensor([-0.1939,  0.0799, -0.6801,  0.0240, -0.6886,  0.2706, -0.6652,  0.4522],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[-0.1939,  0.0799, -0.6801,  0.0234, -0.6885,  0.2706, -0.6652,  0.4525]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.9574e-05, 7.3166e-06, 1.5299e-06, 5.9952e-04, 2.8408e-05, 4.2610e-05,
#          4.2490e-06, 1.0402e-04]], grad_fn=<TBackward0>)
# real y: tensor([-0.1896,  0.0733, -0.6702,  0.0156, -0.6826,  0.2809, -0.6752,  0.4174])
# Epoch: 200
# [Validation]	 J_a: -7.82
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 55.62
# Epoch: 201
# [Validation]	 J_a: -9.78
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 53.66
# Epoch: 202
# [Validation]	 J_a: 2.65
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 66.09
# Epoch: 203
# [Validation]	 J_a: -9.33
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 54.11
# Epoch: 204
# [Validation]	 J_a: 168.17
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 231.60
# Epoch: 205
# [Validation]	 J_a: 121.71
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 185.14
# Epoch: 206
# [Validation]	 J_a: 416.88
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 480.31
# Epoch: 207
# [Validation]	 J_a: 142.61
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 206.05
# Epoch: 208
# [Validation]	 J_a: 743.73
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 807.16
# Epoch: 209
# [Validation]	 J_a: 267.46
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 330.89
# Epoch: 210
# [Validation]	 J_a: 107.82
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 171.25
# Epoch: 211
# [Validation]	 J_a: 49.93
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 113.36
# Epoch: 212
# [Validation]	 J_a: 2.29
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 65.72
# Epoch: 213
# [Validation]	 J_a: 38.05
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 101.48
# Epoch: 214
# [Validation]	 J_a: -7.13
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 56.30
# Epoch: 215
# [Validation]	 J_a: 117.37
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 180.80
# Epoch: 216
# [Validation]	 J_a: 5.05
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 68.48
# Epoch: 217
# [Validation]	 J_a: 60.46
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 123.89
# Epoch: 218
# [Validation]	 J_a: 36.43
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 99.86
# Epoch: 219
# [Validation]	 J_a: 15.43
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 78.86
# Epoch: 220
# [Validation]	 J_a: -22.60
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 40.83
# Epoch: 221
# [Validation]	 J_a: -15.35
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 48.09
# Epoch: 222
# [Validation]	 J_a: 12.65
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 76.08
# Epoch: 223
# [Validation]	 J_a: 37.36
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 100.79
# Epoch: 224
# [Validation]	 J_a: 23.44
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 86.87
# Epoch: 225
# [Validation]	 J_a: -14.14
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 49.29
# Epoch: 226
# [Validation]	 J_a: 121.90
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 185.34
# Epoch: 227
# [Validation]	 J_a: 228.16
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 291.60
# Epoch: 228
# [Validation]	 J_a: 13.79
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 77.22
# Epoch: 229
# [Validation]	 J_a: -0.68
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 62.76
# Epoch: 230
# [Validation]	 J_a: -12.07
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 51.36
# Epoch: 231
# [Validation]	 J_a: 316.05
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 379.48
# Epoch: 232
# [Validation]	 J_a: 65.61
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 129.04
# Epoch: 233
# [Validation]	 J_a: -11.72
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 51.71
# Epoch: 234
# [Validation]	 J_a: -25.60
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 37.84
# Epoch: 235
# [Validation]	 J_a: -18.71
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 44.72
# Epoch: 236
# [Validation]	 J_a: 77.25
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 140.68
# Epoch: 237
# [Validation]	 J_a: -4.86
# [Validation]	 L: -63.4321
# [Validation]	 alpha * MSE: 58.57
# Epoch: 238
# [Validation]	 J_a: -16.27
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 47.17
# Epoch: 239
# [Validation]	 J_a: 23.28
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 86.72
# Epoch: 240
# [Validation]	 J_a: -24.78
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 38.65
# Epoch: 241
# [Validation]	 J_a: 13.95
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 77.38
# Epoch: 242
# [Validation]	 J_a: 0.66
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 64.10
# Epoch: 243
# [Validation]	 J_a: 136.58
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 200.02
# Epoch: 244
# [Validation]	 J_a: -12.04
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 51.40
# Epoch: 245
# [Validation]	 J_a: -20.46
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 42.97
# Epoch: 246
# [Validation]	 J_a: 82.26
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 145.70
# Epoch: 247
# [Validation]	 J_a: 97.59
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 161.02
# Epoch: 248
# [Validation]	 J_a: -3.48
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 59.95
# Epoch: 249
# [Validation]	 J_a: 685.11
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 748.55
# Epoch: 250
# [Validation]	 J_a: 333.93
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 397.37
# Epoch: 251
# [Validation]	 J_a: -5.26
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 58.17
# Epoch: 252
# [Validation]	 J_a: 113.50
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 176.93
# Epoch: 253
# [Validation]	 J_a: 566.65
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 630.08
# Epoch: 254
# [Validation]	 J_a: 142.86
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 206.30
# Epoch: 255
# [Validation]	 J_a: -28.86
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 34.57
# Epoch: 256
# [Validation]	 J_a: 29.77
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 93.20
# Epoch: 257
# [Validation]	 J_a: -24.82
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 38.61
# Epoch: 258
# [Validation]	 J_a: 26.70
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 90.13
# Epoch: 259
# [Validation]	 J_a: 12.44
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 75.87
# Epoch: 260
# [Validation]	 J_a: 77.34
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 140.77
# Epoch: 261
# [Validation]	 J_a: 2.43
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 65.87
# Epoch: 262
# [Validation]	 J_a: 161.84
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 225.27
# Epoch: 263
# [Validation]	 J_a: -20.49
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 42.94
# Epoch: 264
# [Validation]	 J_a: -21.34
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 42.09
# Epoch: 265
# [Validation]	 J_a: 22.61
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 86.04
# Epoch: 266
# [Validation]	 J_a: 19.24
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 82.67
# Epoch: 267
# [Validation]	 J_a: 111.21
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 174.64
# Epoch: 268
# [Validation]	 J_a: -28.28
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 35.15
# Epoch: 269
# [Validation]	 J_a: 126.52
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 189.96
# Epoch: 270
# [Validation]	 J_a: -2.43
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 61.00
# Epoch: 271
# [Validation]	 J_a: 7.67
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 71.10
# Epoch: 272
# [Validation]	 J_a: -26.77
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 36.67
# Epoch: 273
# [Validation]	 J_a: 15.24
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 78.68
# Epoch: 274
# [Validation]	 J_a: -13.50
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 49.93
# Epoch: 275
# [Validation]	 J_a: 85.14
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 148.57
# Epoch: 276
# [Validation]	 J_a: 154.54
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 217.98
# Epoch: 277
# [Validation]	 J_a: -16.20
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 47.24
# Epoch: 278
# [Validation]	 J_a: -10.86
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 52.57
# Epoch: 279
# [Validation]	 J_a: 28.53
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 91.96
# Epoch: 280
# [Validation]	 J_a: -25.83
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 37.60
# Epoch: 281
# [Validation]	 J_a: 307.82
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 371.25
# Epoch: 282
# [Validation]	 J_a: -9.39
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 54.04
# Epoch: 283
# [Validation]	 J_a: 129.00
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 192.44
# Epoch: 284
# [Validation]	 J_a: -6.69
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 56.75
# Epoch: 285
# [Validation]	 J_a: -17.19
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 46.24
# Epoch: 286
# [Validation]	 J_a: -32.73
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 30.70
# Epoch: 287
# [Validation]	 J_a: 491.90
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 555.34
# Epoch: 288
# [Validation]	 J_a: -28.75
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 34.69
# Epoch: 289
# [Validation]	 J_a: -13.16
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 50.27
# Epoch: 290
# [Validation]	 J_a: 220.39
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 283.82
# Epoch: 291
# [Validation]	 J_a: 18.33
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 81.76
# Epoch: 292
# [Validation]	 J_a: 143.09
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 206.53
# Epoch: 293
# [Validation]	 J_a: 117.48
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 180.91
# Epoch: 294
# [Validation]	 J_a: -13.43
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 50.00
# Epoch: 295
# [Validation]	 J_a: -4.61
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 58.83
# Epoch: 296
# [Validation]	 J_a: 49.59
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 113.02
# Epoch: 297
# [Validation]	 J_a: 25.65
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 89.09
# Epoch: 298
# [Validation]	 J_a: -12.82
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 50.61
# Epoch: 299
# [Validation]	 J_a: 21.51
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 84.94
# Epoch: 300, ELBO now is -7.923226356506348, regression loss is 0.0036670430563390255
# pred_y: tensor([-0.6436,  0.4175,  0.3917, -0.2372, -0.0036,  0.0820,  0.4622,  0.2452],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[-0.6436,  0.4175,  0.3917, -0.2370, -0.0034,  0.0820,  0.4622,  0.2452]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.6710e-06, 3.8780e-05, 6.3843e-05, 8.9735e-05, 4.1821e-05, 5.1053e-05,
#          1.4206e-05, 6.8365e-05]], grad_fn=<TBackward0>)
# real y: tensor([-0.6483,  0.4345,  0.4262, -0.2352,  0.0245,  0.1082,  0.4804,  0.2639])
# Epoch: 300
# [Validation]	 J_a: 9.22
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 72.65
# Epoch: 301
# [Validation]	 J_a: -8.53
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 54.90
# Epoch: 302
# [Validation]	 J_a: -7.65
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 55.78
# Epoch: 303
# [Validation]	 J_a: 14.42
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 77.85
# Epoch: 304
# [Validation]	 J_a: -32.62
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 30.81
# Epoch: 305
# [Validation]	 J_a: 59.41
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 122.84
# Epoch: 306
# [Validation]	 J_a: 170.87
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 234.30
# Epoch: 307
# [Validation]	 J_a: -34.35
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 29.08
# Epoch: 308
# [Validation]	 J_a: -28.23
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 35.21
# Epoch: 309
# [Validation]	 J_a: -13.43
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 50.01
# Epoch: 310
# [Validation]	 J_a: 99.25
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 162.69
# Epoch: 311
# [Validation]	 J_a: 550.21
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 613.64
# Epoch: 312
# [Validation]	 J_a: 229.16
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 292.60
# Epoch: 313
# [Validation]	 J_a: -16.81
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 46.62
# Epoch: 314
# [Validation]	 J_a: 3.19
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 66.62
# Epoch: 315
# [Validation]	 J_a: -11.01
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 52.42
# Epoch: 316
# [Validation]	 J_a: 7.52
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 70.96
# Epoch: 317
# [Validation]	 J_a: 8.19
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 71.62
# Epoch: 318
# [Validation]	 J_a: 28.76
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 92.19
# Epoch: 319
# [Validation]	 J_a: -15.34
# [Validation]	 L: -63.4339
# [Validation]	 alpha * MSE: 48.10
# Epoch: 320
# [Validation]	 J_a: -33.32
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 30.11
# Epoch: 321
# [Validation]	 J_a: 17.48
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 80.91
# Epoch: 322
# [Validation]	 J_a: -31.74
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 31.69
# Epoch: 323
# [Validation]	 J_a: -10.98
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 52.45
# Epoch: 324
# [Validation]	 J_a: -32.47
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 30.96
# Epoch: 325
# [Validation]	 J_a: -29.80
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 33.64
# Epoch: 326
# [Validation]	 J_a: 12.28
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 75.71
# Epoch: 327
# [Validation]	 J_a: 15.28
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 78.71
# Epoch: 328
# [Validation]	 J_a: -33.88
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 29.56
# Epoch: 329
# [Validation]	 J_a: -32.45
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 30.98
# Epoch: 330
# [Validation]	 J_a: -29.76
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 33.68
# Epoch: 331
# [Validation]	 J_a: 286.33
# [Validation]	 L: -63.4339
# [Validation]	 alpha * MSE: 349.77
# Epoch: 332
# [Validation]	 J_a: -8.52
# [Validation]	 L: -63.4339
# [Validation]	 alpha * MSE: 54.91
# Epoch: 333
# [Validation]	 J_a: -23.78
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 39.65
# Epoch: 334
# [Validation]	 J_a: -16.44
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 47.00
# Epoch: 335
# [Validation]	 J_a: 29.45
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 92.88
# Epoch: 336
# [Validation]	 J_a: -33.78
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 29.65
# Epoch: 337
# [Validation]	 J_a: -11.37
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 52.07
# Epoch: 338
# [Validation]	 J_a: -27.74
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 35.69
# Epoch: 339
# [Validation]	 J_a: -33.20
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 30.23
# Epoch: 340
# [Validation]	 J_a: 121.28
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 184.71
# Epoch: 341
# [Validation]	 J_a: -26.94
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 36.50
# Epoch: 342
# [Validation]	 J_a: -14.23
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 49.20
# Epoch: 343
# [Validation]	 J_a: 326.68
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 390.11
# Epoch: 344
# [Validation]	 J_a: 116.98
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 180.41
# Epoch: 345
# [Validation]	 J_a: 243.31
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 306.74
# Epoch: 346
# [Validation]	 J_a: -25.27
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 38.16
# Epoch: 347
# [Validation]	 J_a: -21.09
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 42.34
# Epoch: 348
# [Validation]	 J_a: -14.97
# [Validation]	 L: -63.4320
# [Validation]	 alpha * MSE: 48.46
# Epoch: 349
# [Validation]	 J_a: -4.47
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 58.96
# Epoch: 350
# [Validation]	 J_a: -15.08
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 48.36
# Epoch: 351
# [Validation]	 J_a: 0.69
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 64.12
# Epoch: 352
# [Validation]	 J_a: -26.58
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 36.85
# Epoch: 353
# [Validation]	 J_a: -27.99
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 35.45
# Epoch: 354
# [Validation]	 J_a: 41.50
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 104.93
# Epoch: 355
# [Validation]	 J_a: 14.71
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 78.14
# Epoch: 356
# [Validation]	 J_a: -18.42
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 45.01
# Epoch: 357
# [Validation]	 J_a: 40.13
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 103.56
# Epoch: 358
# [Validation]	 J_a: 92.06
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 155.49
# Epoch: 359
# [Validation]	 J_a: -17.88
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 45.55
# Epoch: 360
# [Validation]	 J_a: 1.06
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 64.49
# Epoch: 361
# [Validation]	 J_a: -20.55
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 42.88
# Epoch: 362
# [Validation]	 J_a: -4.19
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 59.24
# Epoch: 363
# [Validation]	 J_a: -37.90
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 25.53
# Epoch: 364
# [Validation]	 J_a: 90.80
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 154.23
# Epoch: 365
# [Validation]	 J_a: -38.18
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 25.25
# Epoch: 366
# [Validation]	 J_a: -30.67
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 32.76
# Epoch: 367
# [Validation]	 J_a: 81.51
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 144.94
# Epoch: 368
# [Validation]	 J_a: 189.08
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 252.51
# Epoch: 369
# [Validation]	 J_a: 102.43
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 165.87
# Epoch: 370
# [Validation]	 J_a: 383.16
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 446.59
# Epoch: 371
# [Validation]	 J_a: 36.55
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 99.99
# Epoch: 372
# [Validation]	 J_a: -6.57
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 56.86
# Epoch: 373
# [Validation]	 J_a: 92.90
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 156.33
# Epoch: 374
# [Validation]	 J_a: 81.68
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 145.11
# Epoch: 375
# [Validation]	 J_a: 60.78
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 124.21
# Epoch: 376
# [Validation]	 J_a: 5.24
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 68.68
# Epoch: 377
# [Validation]	 J_a: -21.43
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 42.00
# Epoch: 378
# [Validation]	 J_a: 109.33
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 172.76
# Epoch: 379
# [Validation]	 J_a: -34.12
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 29.31
# Epoch: 380
# [Validation]	 J_a: 50.76
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 114.19
# Epoch: 381
# [Validation]	 J_a: 162.26
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 225.69
# Epoch: 382
# [Validation]	 J_a: 174.52
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 237.96
# Epoch: 383
# [Validation]	 J_a: 12.58
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 76.01
# Epoch: 384
# [Validation]	 J_a: -25.93
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 37.51
# Epoch: 385
# [Validation]	 J_a: -21.85
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 41.59
# Epoch: 386
# [Validation]	 J_a: 64.00
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 127.43
# Epoch: 387
# [Validation]	 J_a: 119.19
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 182.62
# Epoch: 388
# [Validation]	 J_a: -30.41
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 33.02
# Epoch: 389
# [Validation]	 J_a: -30.52
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 32.92
# Epoch: 390
# [Validation]	 J_a: 25.24
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 88.68
# Epoch: 391
# [Validation]	 J_a: 7.13
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 70.56
# Epoch: 392
# [Validation]	 J_a: 181.47
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 244.90
# Epoch: 393
# [Validation]	 J_a: 98.63
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 162.06
# Epoch: 394
# [Validation]	 J_a: -0.83
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 62.61
# Epoch: 395
# [Validation]	 J_a: -22.85
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 40.58
# Epoch: 396
# [Validation]	 J_a: -31.82
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 31.61
# Epoch: 397
# [Validation]	 J_a: -20.70
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 42.74
# Epoch: 398
# [Validation]	 J_a: 71.38
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 134.81
# Epoch: 399
# [Validation]	 J_a: 102.07
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 165.50
# Epoch: 400, ELBO now is -7.672457218170166, regression loss is 0.002107932697981596
# pred_y: tensor([ 0.0611, -0.0550, -0.2682, -0.0331, -0.2699,  0.0359,  0.2087,  0.6869],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.0611, -0.0550, -0.2682, -0.0331, -0.2699,  0.0360,  0.2087,  0.6871]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.3484e-05, 1.7079e-04, 2.5183e-05, 4.5502e-06, 3.6390e-05, 3.5305e-05,
#          1.1173e-05, 7.7046e-05]], grad_fn=<TBackward0>)
# real y: tensor([ 0.0456, -0.0738, -0.2769, -0.0262, -0.2850,  0.0222,  0.1915,  0.7130])
# Epoch: 400
# [Validation]	 J_a: 234.95
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 298.39
# Epoch: 401
# [Validation]	 J_a: -7.50
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 55.93
# Epoch: 402
# [Validation]	 J_a: -38.41
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 25.02
# Epoch: 403
# [Validation]	 J_a: 16.48
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 79.91
# Epoch: 404
# [Validation]	 J_a: 10.43
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 73.87
# Epoch: 405
# [Validation]	 J_a: -1.06
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 62.37
# Epoch: 406
# [Validation]	 J_a: 10.75
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 74.18
# Epoch: 407
# [Validation]	 J_a: -28.18
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 35.25
# Epoch: 408
# [Validation]	 J_a: 17.35
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 80.78
# Epoch: 409
# [Validation]	 J_a: -15.70
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 47.73
# Epoch: 410
# [Validation]	 J_a: -34.23
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 29.20
# Epoch: 411
# [Validation]	 J_a: -1.97
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 61.46
# Epoch: 412
# [Validation]	 J_a: 209.88
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 273.32
# Epoch: 413
# [Validation]	 J_a: -35.69
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 27.74
# Epoch: 414
# [Validation]	 J_a: 70.63
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 134.06
# Epoch: 415
# [Validation]	 J_a: -16.74
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 46.69
# Epoch: 416
# [Validation]	 J_a: -1.66
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 61.77
# Epoch: 417
# [Validation]	 J_a: -33.20
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 30.23
# Epoch: 418
# [Validation]	 J_a: -17.22
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 46.21
# Epoch: 419
# [Validation]	 J_a: -26.52
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 36.91
# Epoch: 420
# [Validation]	 J_a: -7.44
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 55.99
# Epoch: 421
# [Validation]	 J_a: -37.73
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 25.70
# Epoch: 422
# [Validation]	 J_a: 143.93
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 207.36
# Epoch: 423
# [Validation]	 J_a: 3.49
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 66.93
# Epoch: 424
# [Validation]	 J_a: 37.67
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 101.10
# Epoch: 425
# [Validation]	 J_a: 116.37
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 179.80
# Epoch: 426
# [Validation]	 J_a: 108.86
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 172.29
# Epoch: 427
# [Validation]	 J_a: -31.74
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 31.69
# Epoch: 428
# [Validation]	 J_a: 15.68
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 79.12
# Epoch: 429
# [Validation]	 J_a: 18.20
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 81.63
# Epoch: 430
# [Validation]	 J_a: -22.19
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 41.25
# Epoch: 431
# [Validation]	 J_a: 5.30
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 68.73
# Epoch: 432
# [Validation]	 J_a: -10.55
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 52.88
# Epoch: 433
# [Validation]	 J_a: 61.51
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 124.94
# Epoch: 434
# [Validation]	 J_a: -41.69
# [Validation]	 L: -63.4324
# [Validation]	 alpha * MSE: 21.74
# Epoch: 435
# [Validation]	 J_a: -37.17
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 26.26
# Epoch: 436
# [Validation]	 J_a: -0.82
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 62.61
# Epoch: 437
# [Validation]	 J_a: -35.34
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 28.09
# Epoch: 438
# [Validation]	 J_a: -20.65
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 42.78
# Epoch: 439
# [Validation]	 J_a: -39.34
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 24.09
# Epoch: 440
# [Validation]	 J_a: 57.72
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 121.15
# Epoch: 441
# [Validation]	 J_a: -18.12
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 45.32
# Epoch: 442
# [Validation]	 J_a: 71.27
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 134.70
# Epoch: 443
# [Validation]	 J_a: 16.66
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 80.09
# Epoch: 444
# [Validation]	 J_a: 120.24
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 183.67
# Epoch: 445
# [Validation]	 J_a: -40.12
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 23.31
# Epoch: 446
# [Validation]	 J_a: 28.65
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 92.08
# Epoch: 447
# [Validation]	 J_a: -35.34
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 28.10
# Epoch: 448
# [Validation]	 J_a: 38.30
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 101.74
# Epoch: 449
# [Validation]	 J_a: -4.60
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 58.83
# Epoch: 450
# [Validation]	 J_a: 25.34
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 88.77
# Epoch: 451
# [Validation]	 J_a: -36.44
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 27.00
# Epoch: 452
# [Validation]	 J_a: 35.90
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 99.33
# Epoch: 453
# [Validation]	 J_a: 37.85
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 101.29
# Epoch: 454
# [Validation]	 J_a: -33.82
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 29.61
# Epoch: 455
# [Validation]	 J_a: -24.74
# [Validation]	 L: -63.4322
# [Validation]	 alpha * MSE: 38.69
# Epoch: 456
# [Validation]	 J_a: -39.57
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 23.86
# Epoch: 457
# [Validation]	 J_a: -13.36
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 50.07
# Epoch: 458
# [Validation]	 J_a: 355.34
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 418.77
# Epoch: 459
# [Validation]	 J_a: 251.50
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 314.93
# Epoch: 460
# [Validation]	 J_a: -19.71
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 43.72
# Epoch: 461
# [Validation]	 J_a: -0.43
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 63.00
# Epoch: 462
# [Validation]	 J_a: -43.06
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 20.37
# Epoch: 463
# [Validation]	 J_a: 462.45
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 525.89
# Epoch: 464
# [Validation]	 J_a: 56.22
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 119.66
# Epoch: 465
# [Validation]	 J_a: -42.01
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 21.42
# Epoch: 466
# [Validation]	 J_a: -33.45
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 29.98
# Epoch: 467
# [Validation]	 J_a: -14.00
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 49.43
# Epoch: 468
# [Validation]	 J_a: 32.50
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 95.93
# Epoch: 469
# [Validation]	 J_a: 176.86
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 240.30
# Epoch: 470
# [Validation]	 J_a: 40.43
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 103.87
# Epoch: 471
# [Validation]	 J_a: 68.40
# [Validation]	 L: -63.4322
# [Validation]	 alpha * MSE: 131.83
# Epoch: 472
# [Validation]	 J_a: 43.71
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 107.14
# Epoch: 473
# [Validation]	 J_a: 9.07
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 72.51
# Epoch: 474
# [Validation]	 J_a: -39.40
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 24.04
# Epoch: 475
# [Validation]	 J_a: -42.75
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 20.68
# Epoch: 476
# [Validation]	 J_a: 265.95
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 329.38
# Epoch: 477
# [Validation]	 J_a: -34.27
# [Validation]	 L: -63.4322
# [Validation]	 alpha * MSE: 29.16
# Epoch: 478
# [Validation]	 J_a: 29.35
# [Validation]	 L: -63.4330
# ...
# [Validation]	 alpha * MSE: 18.25
# Epoch: 4847
# [Validation]	 J_a: -58.91
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 4.52
# Epoch: 4848
# [Validation]	 J_a: -48.14
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 15.29
# Epoch: 4849
# [Validation]	 J_a: -58.21
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 5.22
# Epoch: 4850
# [Validation]	 J_a: -61.19
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.24
# Epoch: 4851
# [Validation]	 J_a: -48.09
# [Validation]	 L: -63.4323
# [Validation]	 alpha * MSE: 15.35
# Epoch: 4852
# [Validation]	 J_a: -57.10
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 6.33
# Epoch: 4853
# [Validation]	 J_a: -44.86
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 18.58
# Epoch: 4854
# [Validation]	 J_a: -34.12
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 29.31
# Epoch: 4855
# [Validation]	 J_a: -58.94
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 4.49
# Epoch: 4856
# [Validation]	 J_a: -60.87
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 2.56
# Epoch: 4857
# [Validation]	 J_a: -6.50
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 56.93
# Epoch: 4858
# [Validation]	 J_a: -45.44
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 17.99
# Epoch: 4859
# [Validation]	 J_a: -60.41
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 3.03
# Epoch: 4860
# [Validation]	 J_a: -42.21
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 21.22
# Epoch: 4861
# [Validation]	 J_a: -60.58
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 2.85
# Epoch: 4862
# [Validation]	 J_a: -35.41
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 28.02
# Epoch: 4863
# [Validation]	 J_a: -60.07
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 3.36
# Epoch: 4864
# [Validation]	 J_a: -57.80
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 5.64
# Epoch: 4865
# [Validation]	 J_a: -58.74
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 4.70
# Epoch: 4866
# [Validation]	 J_a: -58.96
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 4.47
# Epoch: 4867
# [Validation]	 J_a: -38.72
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 24.72
# Epoch: 4868
# [Validation]	 J_a: -59.78
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 3.65
# Epoch: 4869
# [Validation]	 J_a: -52.41
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 11.03
# Epoch: 4870
# [Validation]	 J_a: -49.94
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 13.50
# Epoch: 4871
# [Validation]	 J_a: 13.75
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 77.18
# Epoch: 4872
# [Validation]	 J_a: -52.65
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 10.79
# Epoch: 4873
# [Validation]	 J_a: -61.34
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 2.09
# Epoch: 4874
# [Validation]	 J_a: -59.29
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 4.15
# Epoch: 4875
# [Validation]	 J_a: -59.25
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 4.18
# Epoch: 4876
# [Validation]	 J_a: -59.54
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 3.89
# Epoch: 4877
# [Validation]	 J_a: -60.85
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 2.58
# Epoch: 4878
# [Validation]	 J_a: -57.64
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 5.79
# Epoch: 4879
# [Validation]	 J_a: -20.98
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 42.45
# Epoch: 4880
# [Validation]	 J_a: -58.76
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 4.68
# Epoch: 4881
# [Validation]	 J_a: -51.98
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 11.45
# Epoch: 4882
# [Validation]	 J_a: -59.37
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 4.06
# Epoch: 4883
# [Validation]	 J_a: -45.41
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 18.03
# Epoch: 4884
# [Validation]	 J_a: -54.35
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 9.08
# Epoch: 4885
# [Validation]	 J_a: 149.40
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 212.83
# Epoch: 4886
# [Validation]	 J_a: -61.29
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 2.14
# Epoch: 4887
# [Validation]	 J_a: -61.31
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 2.13
# Epoch: 4888
# [Validation]	 J_a: -61.44
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.00
# Epoch: 4889
# [Validation]	 J_a: -57.80
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 5.63
# Epoch: 4890
# [Validation]	 J_a: -56.37
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 7.07
# Epoch: 4891
# [Validation]	 J_a: -59.19
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 4.25
# Epoch: 4892
# [Validation]	 J_a: -56.49
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 6.94
# Epoch: 4893
# [Validation]	 J_a: -36.66
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 26.77
# Epoch: 4894
# [Validation]	 J_a: -53.67
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 9.76
# Epoch: 4895
# [Validation]	 J_a: -48.59
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 14.84
# Epoch: 4896
# [Validation]	 J_a: -59.72
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 3.72
# Epoch: 4897
# [Validation]	 J_a: -60.07
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 3.37
# Epoch: 4898
# [Validation]	 J_a: 31.28
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 94.71
# Epoch: 4899
# [Validation]	 J_a: -59.15
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 4.28
# Epoch: 4900, ELBO now is -7.631598472595215, regression loss is 0.00010511595610296354
# pred_y: tensor([ 0.2252, -0.0977,  0.2278,  0.0037,  0.7073,  0.0208,  0.0401,  0.1342],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.2252, -0.0977,  0.2278,  0.0037,  0.7073,  0.0208,  0.0401,  0.1342]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.3176e-10, 1.0692e-06, 8.5008e-08, 2.2298e-09, 5.4295e-10, 4.7386e-08,
#          1.1887e-07, 1.0571e-06]], grad_fn=<TBackward0>)
# real y: tensor([ 0.2252, -0.0978,  0.2223,  0.0053,  0.7016,  0.0164,  0.0356,  0.1343])
# Epoch: 4900
# [Validation]	 J_a: -58.70
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 4.74
# Epoch: 4901
# [Validation]	 J_a: -59.54
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 3.90
# Epoch: 4902
# [Validation]	 J_a: -46.52
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 16.91
# Epoch: 4903
# [Validation]	 J_a: -40.43
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 23.01
# Epoch: 4904
# [Validation]	 J_a: -37.61
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 25.82
# Epoch: 4905
# [Validation]	 J_a: -61.31
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 2.12
# Epoch: 4906
# [Validation]	 J_a: -34.50
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 28.93
# Epoch: 4907
# [Validation]	 J_a: -17.92
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 45.52
# Epoch: 4908
# [Validation]	 J_a: -57.82
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 5.61
# Epoch: 4909
# [Validation]	 J_a: -52.19
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 11.24
# Epoch: 4910
# [Validation]	 J_a: -46.23
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 17.20
# Epoch: 4911
# [Validation]	 J_a: -61.22
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.22
# Epoch: 4912
# [Validation]	 J_a: -57.42
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 6.01
# Epoch: 4913
# [Validation]	 J_a: -57.78
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 5.65
# Epoch: 4914
# [Validation]	 J_a: -60.02
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 3.42
# Epoch: 4915
# [Validation]	 J_a: -49.44
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 14.00
# Epoch: 4916
# [Validation]	 J_a: -60.81
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 2.62
# Epoch: 4917
# [Validation]	 J_a: -43.72
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 19.71
# Epoch: 4918
# [Validation]	 J_a: -60.89
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 2.54
# Epoch: 4919
# [Validation]	 J_a: -48.81
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 14.63
# Epoch: 4920
# [Validation]	 J_a: -61.58
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 1.85
# Epoch: 4921
# [Validation]	 J_a: -46.76
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 16.68
# Epoch: 4922
# [Validation]	 J_a: -60.26
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 3.17
# Epoch: 4923
# [Validation]	 J_a: -43.16
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 20.28
# Epoch: 4924
# [Validation]	 J_a: -53.40
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 10.04
# Epoch: 4925
# [Validation]	 J_a: -58.33
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 5.10
# Epoch: 4926
# [Validation]	 J_a: -57.18
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 6.25
# Epoch: 4927
# [Validation]	 J_a: -57.00
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 6.43
# Epoch: 4928
# [Validation]	 J_a: -46.57
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 16.86
# Epoch: 4929
# [Validation]	 J_a: -58.26
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 5.17
# Epoch: 4930
# [Validation]	 J_a: -59.24
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 4.19
# Epoch: 4931
# [Validation]	 J_a: -50.84
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 12.59
# Epoch: 4932
# [Validation]	 J_a: -58.80
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 4.63
# Epoch: 4933
# [Validation]	 J_a: -7.00
# [Validation]	 L: -63.4325
# [Validation]	 alpha * MSE: 56.44
# Epoch: 4934
# [Validation]	 J_a: -58.30
# [Validation]	 L: -63.4337
# [Validation]	 alpha * MSE: 5.13
# Epoch: 4935
# [Validation]	 J_a: -58.52
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 4.91
# Epoch: 4936
# [Validation]	 J_a: -61.43
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.00
# Epoch: 4937
# [Validation]	 J_a: -61.40
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 2.04
# Epoch: 4938
# [Validation]	 J_a: -59.92
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 3.52
# Epoch: 4939
# [Validation]	 J_a: -60.87
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.57
# Epoch: 4940
# [Validation]	 J_a: -60.74
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 2.70
# Epoch: 4941
# [Validation]	 J_a: -58.33
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 5.11
# Epoch: 4942
# [Validation]	 J_a: -51.75
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 11.68
# Epoch: 4943
# [Validation]	 J_a: -57.98
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 5.46
# Epoch: 4944
# [Validation]	 J_a: -57.82
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 5.61
# Epoch: 4945
# [Validation]	 J_a: -61.41
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.02
# Epoch: 4946
# [Validation]	 J_a: -53.61
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 9.82
# Epoch: 4947
# [Validation]	 J_a: -59.43
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 4.00
# Epoch: 4948
# [Validation]	 J_a: -43.44
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 19.99
# Epoch: 4949
# [Validation]	 J_a: -59.11
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 4.33
# Epoch: 4950
# [Validation]	 J_a: -58.88
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 4.55
# Epoch: 4951
# [Validation]	 J_a: -56.82
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 6.62
# Epoch: 4952
# [Validation]	 J_a: -51.45
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 11.98
# Epoch: 4953
# [Validation]	 J_a: -33.88
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 29.55
# Epoch: 4954
# [Validation]	 J_a: -44.89
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 18.54
# Epoch: 4955
# [Validation]	 J_a: -60.06
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 3.38
# Epoch: 4956
# [Validation]	 J_a: -60.18
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 3.25
# Epoch: 4957
# [Validation]	 J_a: -59.26
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 4.17
# Epoch: 4958
# [Validation]	 J_a: -59.50
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 3.93
# Epoch: 4959
# [Validation]	 J_a: -22.90
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 40.54
# Epoch: 4960
# [Validation]	 J_a: -58.72
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 4.71
# Epoch: 4961
# [Validation]	 J_a: -57.03
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 6.40
# Epoch: 4962
# [Validation]	 J_a: -61.48
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 1.95
# Epoch: 4963
# [Validation]	 J_a: -56.06
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 7.37
# Epoch: 4964
# [Validation]	 J_a: -55.46
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 7.98
# Epoch: 4965
# [Validation]	 J_a: -47.71
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 15.72
# Epoch: 4966
# [Validation]	 J_a: -53.56
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 9.87
# Epoch: 4967
# [Validation]	 J_a: -58.12
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 5.32
# Epoch: 4968
# [Validation]	 J_a: -60.96
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 2.47
# Epoch: 4969
# [Validation]	 J_a: -60.14
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 3.29
# Epoch: 4970
# [Validation]	 J_a: -23.87
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 39.56
# Epoch: 4971
# [Validation]	 J_a: -54.11
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 9.32
# Epoch: 4972
# [Validation]	 J_a: 120.89
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 184.32
# Epoch: 4973
# [Validation]	 J_a: -53.14
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 10.29
# Epoch: 4974
# [Validation]	 J_a: -47.85
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 15.58
# Epoch: 4975
# [Validation]	 J_a: -60.94
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 2.49
# Epoch: 4976
# [Validation]	 J_a: -60.08
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 3.35
# Epoch: 4977
# [Validation]	 J_a: 16.11
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 79.55
# Epoch: 4978
# [Validation]	 J_a: -56.43
# [Validation]	 L: -63.4328
# [Validation]	 alpha * MSE: 7.00
# Epoch: 4979
# [Validation]	 J_a: -58.35
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 5.08
# Epoch: 4980
# [Validation]	 J_a: 57.54
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 120.98
# Epoch: 4981
# [Validation]	 J_a: -59.09
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 4.35
# Epoch: 4982
# [Validation]	 J_a: -52.03
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 11.40
# Epoch: 4983
# [Validation]	 J_a: -42.22
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 21.21
# Epoch: 4984
# [Validation]	 J_a: -47.48
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 15.95
# Epoch: 4985
# [Validation]	 J_a: 12.76
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 76.19
# Epoch: 4986
# [Validation]	 J_a: -31.79
# [Validation]	 L: -63.4326
# [Validation]	 alpha * MSE: 31.65
# Epoch: 4987
# [Validation]	 J_a: -45.29
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 18.14
# Epoch: 4988
# [Validation]	 J_a: -40.29
# [Validation]	 L: -63.4334
# [Validation]	 alpha * MSE: 23.14
# Epoch: 4989
# [Validation]	 J_a: -39.71
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 23.72
# Epoch: 4990
# [Validation]	 J_a: -50.73
# [Validation]	 L: -63.4336
# [Validation]	 alpha * MSE: 12.71
# Epoch: 4991
# [Validation]	 J_a: -60.08
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 3.36
# Epoch: 4992
# [Validation]	 J_a: -59.50
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 3.93
# Epoch: 4993
# [Validation]	 J_a: -55.71
# [Validation]	 L: -63.4331
# [Validation]	 alpha * MSE: 7.72
# Epoch: 4994
# [Validation]	 J_a: -54.91
# [Validation]	 L: -63.4332
# [Validation]	 alpha * MSE: 8.53
# Epoch: 4995
# [Validation]	 J_a: -60.97
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 2.46
# Epoch: 4996
# [Validation]	 J_a: -61.38
# [Validation]	 L: -63.4329
# [Validation]	 alpha * MSE: 2.05
# Epoch: 4997
# [Validation]	 J_a: -54.49
# [Validation]	 L: -63.4327
# [Validation]	 alpha * MSE: 8.95
# Epoch: 4998
# [Validation]	 J_a: 169.70
# [Validation]	 L: -63.4330
# [Validation]	 alpha * MSE: 233.13
# Epoch: 4999
# [Validation]	 J_a: -59.75
# [Validation]	 L: -63.4333
# [Validation]	 alpha * MSE: 3.69
# Epoch: 5000, ELBO now is -8.373800277709961, regression loss is 0.0004892444121651351
# pred_y: tensor([ 0.1807,  0.2818, -0.3863,  0.1009,  0.0129,  0.2176,  0.9618, -0.9356],
#        grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.1807,  0.2818, -0.3863,  0.1009,  0.0129,  0.2176,  0.9618, -0.9356]],
#        grad_fn=<TBackward0>)
# y_std: tensor([[1.3903e-08, 1.7121e-08, 3.0545e-09, 5.0170e-08, 1.4666e-06, 4.5407e-08,
#          2.5977e-11, 1.7002e-15]], grad_fn=<TBackward0>)
# real y: tensor([ 0.1706,  0.2722, -0.3817,  0.0942,  0.0086,  0.2150,  0.9480, -0.9319])
# Epoch: 5000
# [Validation]	 J_a: -49.41
# [Validation]	 L: -63.4335
# [Validation]	 alpha * MSE: 14.03

# %%
# Save the list  
torch.save([J_collect, L_collect, MSE_collect], './save/cur_JLMSElist.pt')  
torch.save(model.state_dict(), "./save/model_cur.pt")
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_28656\1401418847.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_list = torch.load('./save/cur_JLMSElist.pt')

# %%
# To load the list back  
loaded_list = torch.load('./save/cur_JLMSElist.pt')  
test = DeepGenerativeModel([784, y_dim, z_dim, h_dim])
test.load_state_dict(torch.load("./model_cur.pt"))
test.eval()

# %% [markdown]
# ## Conditional generation
#
# When the model is done training you can generate samples conditionally given some normal distributed noise $z$ and a label $y$.
#
# *The model below has only trained for 10 iterations, so the perfomance is not representative*.

# %%
# Plot
plt.figure(figsize=(10, 6))

epochs = range(1, EPOCH)  # Ensure EPOCH includes the last epoch

# # Detach tensors and convert to NumPy
# L_collect_np = [l.detach().numpy() for l in L_collect]
# MSE_collect_np = [m.detach().numpy() for m in MSE_collect]

# Plot the metrics
plt.plot(epochs, J_collect, label='J_alpha', marker='o')
# plt.plot(epochs, L_collect_np, label='L_collect', marker='s')
# plt.plot(epochs, MSE_collect_np, label='MSE_collect', marker='^')

# Add labels, legend, and grid
plt.xlabel('Epoch')
plt.ylabel('Values')
plt.title('Metrics Over Epochs')
plt.legend()
plt.grid(True)
# plt.ylim(-1170, -1000)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import torch
from torch.autograd import Variable

# Initialize the figure and 2x5 axes array
fig, axarr = plt.subplots(2, 5, figsize=(18, 10), subplot_kw={'projection': '3d'})

# Set the range for T and K
T = np.linspace(0.1, 0.6, 28)
K = np.linspace(0.7, 1.3, 28)
K, T = np.meshgrid(K, T)

y_values = np.linspace(cur_0.min(), cur_0.max(), 10)
z = Variable(torch.randn(1, z_dim))

model.eval()
for i, y_value in enumerate(y_values):
    # Set y to a specific value for each sample
    y = Variable(torch.tensor([y_value]).repeat(1, 1))
    # print("to generate y:", y.t()/10)

    # Generate samples from the model
    x_mu = model.sample(z, y)
    # print("real y:", x_mu.mean(dim=1).t()/10)
    # print("regress y:", model.regress(x_mu)[0].t())
    # print("y_mu:", model.regress(x_mu)[1].t())
    # print("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
    # print()
    samples = x_mu.data.view(-1, 1, 28, 28).numpy()

    # Determine subplot position (row, column)
    row, col = divmod(i, 5)
    ax = axarr[row, col]
    
    # Plot the surface
    surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')

    # Set title and adjust z-axis limits for consistency
    ax.set_title(f'''to generate cur: {y_value}\n 
                 regress cur: {model.regress(x_mu)[0].t()[0][0]}\n 
                 cur_mu: {model.regress(x_mu)[1].t()[0][0]}\n 
                 cur_std: {model.regress(x_mu)[2].mul(0.5).exp_().t()[0][0]}''',
                 linespacing=0.4)
    # ax.set_zlim(-0.2, 0.8)  # Adjust the z-axis limits to be consistent across all plots

# Show the final figure with all subplots
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
# import torch
# from torch.autograd import Variable

# # Initialize the figure and 2x5 axes array
# fig, axarr = plt.subplots(2, 5, figsize=(18, 10), subplot_kw={'projection': '3d'})

# # Set the range for T and K
# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# T, K = np.meshgrid(T, K)

# y_values = np.linspace(cur_0.min(), cur_0.max(), 10)
# z = Variable(torch.randn(1, z_dim))

# model.eval()
# for i, y_value in enumerate(y_values):
#     # Set y to a specific value for each sample
#     y = Variable(torch.tensor([y_value]).repeat(1, 1))
#     print("to generate y:", y.t()/10)

#     # Generate samples from the model
#     x_mu = model.sample(z, y)
#     print("real y:", x_mu.mean(dim=1).t()/10)
#     print("regress y:", model.regress(x_mu)[0].t())
#     print("y_mu:", model.regress(x_mu)[1].t())
#     print("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     print()
#     samples = x_mu.data.view(-1, 1, 28, 28).numpy()

#     # Determine subplot position (row, column)
#     row, col = divmod(i, 5)
#     ax = axarr[row, col]
    
#     # Plot the surface
#     surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')

#     # Set title and adjust z-axis limits for consistency
#     ax.set_title("to generate y:", y.t())
#     ax.set_title("real y:", x_mu.mean(dim=1).t())
#     ax.set_title("regress y:", model.regress(x_mu)[0].t())
#     ax.set_title("y_mu:", model.regress(x_mu)[1].t())
#     ax.set_title("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     ax.set_zlim(-0.2, 0.8)  # Adjust the z-axis limits to be consistent across all plots

# # Show the final figure with all subplots
# plt.tight_layout()
# plt.show()
# Out:
# to generate y: tensor([[-0.1858]], dtype=torch.float64)
# real y: tensor([0.0408], grad_fn=<DivBackward0>)
# regress y: tensor([[-1.8437]], grad_fn=<TBackward0>)
# y_mu: tensor([[-1.8437]], grad_fn=<TBackward0>)
# y_std: tensor([[1.0541e-15]], grad_fn=<TBackward0>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 41
#      38 surf = ax.plot_surface(K, T, samples[0, 0, :, :], cmap='viridis')
#      40 # Set title and adjust z-axis limits for consistency
# ---> 41 ax.set_title("to generate y:", y.t())
#      42 ax.set_title("real y:", x_mu.mean(dim=1).t())
#      43 ax.set_title("regress y:", model.regress(x_mu)[0].t())
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2937, in Axes3D.set_title(self, label, fontdict, loc, **kwargs)
#    2935 def set_title(self, label, fontdict=None, loc='center', **kwargs):
#    2936     # docstring inherited
# -> 2937     ret = super().set_title(label, fontdict=fontdict, loc=loc, **kwargs)
#    2938     (x, y) = self.title.get_position()
#    2939     self.title.set_y(0.92 * y)
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\axes\_axes.py:205, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     203 title.update(default)
#     204 if fontdict is not None:
# --> 205     title.update(fontdict)
#     206 title._internal_update(kwargs)
#     207 return title
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\text.py:197, in Text.update(self, kwargs)
#     194 def update(self, kwargs):
#     195     # docstring inherited
#     196     ret = []
# --> 197     kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198     sentinel = object()  # bbox can be None, so use another sentinel.
#     199     # Update fontproperties first, as it has lowest priority.
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\matplotlib\cbook.py:1840, in normalize_kwargs(kw, alias_mapping)
#    1837 canonical_to_seen = {}
#    1838 ret = {}  # output dictionary
# -> 1840 for k, v in kw.items():
#    1841     canonical = to_canonical.get(k, k)
#    1842     if canonical in canonical_to_seen:
#
# AttributeError: 'Tensor' object has no attribute 'items'

# %%
# !3 lines

# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
# import torch
# from torch.autograd import Variable

# # Initialize figure and 2x5 axes array
# fig, axarr = plt.subplots(3, 10, figsize=(30, 15), subplot_kw={'projection': '3d'})

# # Set the range for T and K
# T = np.linspace(0.1, 0.6, 28)
# K = np.linspace(0.7, 1.3, 28)
# T, K = np.meshgrid(T, K)

# z = Variable(torch.randn(16, z_dim))
# if cuda:
#     z = z.cuda(device=0)

# model.eval()
# for dim in range(3):  # Loop over each dimension of the 3D y
#     level_min, level_max = level.min().item(), level.max().item()
#     y_min = tar[:, dim].min()
#     y_max = tar[:, dim].max()
#     y_values = np.linspace(y_min, y_max, 10)
#     for i, y_value in enumerate(y_values):
#         # Set y to a specific value for the current dimension, keep others fixed
#         y = Variable(torch.zeros(16, 3))  # Initialize y as a 3D tensor
#         y[:, 0] = tar[:, 0].mean()
#         y[:, 1] = tar[:, 1].mean()
#         y[:, 2] = tar[:, 2].mean()
#         y[:, dim] = y_value  # Set only the current dimension to y_value
#         if cuda:
#             y = y.cuda(device=0)

#         # Generate samples from the model
#         x_mu = model.sample(z, y)

#         samples = x_mu.data.view(-1, 1, 28, 28).cpu().numpy()

#         # Determine subplot position (row, column)
#         row = dim  # Row for the specific y dimension
#         col = i    # Column for the y_value within that dimension
#         ax = axarr[row, col]

#         # Plot the surface
#         surf = ax.plot_surface(K, T, samples[0, 0, :, :].t(), cmap='viridis')

#         # Set title and adjust z-axis limits for consistency
#         ax.set_title(f'y_dim {dim+1} value = {y_value:.2f}')
#         ax.set_zlim(0, 1)  # Adjust the z-axis limits to be consistent across all plots
        
#     print("Real y:", y.t())
#     print("Regressed y:", model.regress(x_mu)[0].t())
#     print("y_mu:", model.regress(x_mu)[1].t())
#     print("y_std:", model.regress(x_mu)[2].mul(0.5).exp_().t())
#     print()

# # Show the final figure with all subplots
# plt.tight_layout()
# plt.show()
# Out:
# Real y: tensor([[0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892,
#          0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892, 0.7892],
#         [0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451,
#          0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451],
#         [0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051,
#          0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051]],
#        device='cuda:0')
# Regressed y: tensor([[ 7.8840e-01,  7.8258e-01,  7.7937e-01,  7.8023e-01,  7.8572e-01,
#           7.8482e-01,  7.8478e-01,  7.8415e-01,  7.8414e-01,  7.8386e-01,
#           7.8620e-01,  7.8209e-01,  7.8869e-01,  7.8371e-01,  7.8184e-01,
#           7.7891e-01],
#         [ 6.6628e-01,  6.1642e-01,  5.7713e-01,  6.2144e-01,  6.1801e-01,
#           6.0612e-01,  5.7426e-01,  6.1050e-01,  6.2689e-01,  5.9976e-01,
#           7.0403e-01,  6.7778e-01,  6.9711e-01,  6.5862e-01,  5.5844e-01,
#           4.5793e-01],
#         [ 2.3757e-02,  2.4085e-02,  1.6401e-02,  1.4024e-02,  2.1754e-02,
#           4.6781e-02,  3.4596e-02,  2.2887e-02,  2.0093e-02,  3.9616e-02,
#           1.8639e-02, -7.6220e-04, -3.5570e-03,  3.9778e-02,  5.0133e-02,
#           5.9738e-02]], device='cuda:0', grad_fn=<TBackward0>)
# y_mu: tensor([[ 7.8840e-01,  7.8258e-01,  7.7937e-01,  7.8023e-01,  7.8572e-01,
#           7.8482e-01,  7.8478e-01,  7.8415e-01,  7.8414e-01,  7.8386e-01,
#           7.8620e-01,  7.8209e-01,  7.8869e-01,  7.8371e-01,  7.8184e-01,
#           7.7891e-01],
#         [ 6.6628e-01,  6.1642e-01,  5.7713e-01,  6.2144e-01,  6.1801e-01,
#           6.0612e-01,  5.7426e-01,  6.1050e-01,  6.2689e-01,  5.9976e-01,
#           7.0403e-01,  6.7778e-01,  6.9711e-01,  6.5862e-01,  5.5844e-01,
#           4.5793e-01],
#         [ 2.3757e-02,  2.4085e-02,  1.6401e-02,  1.4024e-02,  2.1754e-02,
#           4.6781e-02,  3.4597e-02,  2.2887e-02,  2.0092e-02,  3.9616e-02,
#           1.8639e-02, -7.6204e-04, -3.5572e-03,  3.9778e-02,  5.0133e-02,
#           5.9739e-02]], device='cuda:0', grad_fn=<TBackward0>)
# y_std: tensor([[2.4366e-10, 3.0760e-10, 3.6357e-10, 3.4702e-10, 2.7795e-10, 2.6570e-10,
#          2.8189e-10, 2.9113e-10, 2.9379e-10, 2.7354e-10, 2.6209e-10, 3.2365e-10,
#          2.6228e-10, 2.7783e-10, 3.0289e-10, 3.3475e-10],
#         [8.2642e-09, 1.0028e-08, 1.1485e-08, 1.1133e-08, 9.1851e-09, 8.8059e-09,
#          9.2166e-09, 9.5561e-09, 9.6516e-09, 9.0204e-09, 8.8696e-09, 1.0578e-08,
#          8.8594e-09, 9.2414e-09, 9.7719e-09, 1.0446e-08],
#         [2.3149e-07, 2.6666e-07, 2.9453e-07, 2.9164e-07, 2.4822e-07, 2.3834e-07,
#          2.4480e-07, 2.5552e-07, 2.5947e-07, 2.4246e-07, 2.4890e-07, 2.8579e-07,
#          2.4843e-07, 2.5301e-07, 2.5529e-07, 2.5994e-07]], device='cuda:0',
#        grad_fn=<TBackward0>)
#
# Real y: tensor([[5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01,
#          5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01,
#          5.8500e-01, 5.8500e-01, 5.8500e-01, 5.8500e-01],
#         [7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00,
#          7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00,
#          7.2859e+00, 7.2859e+00, 7.2859e+00, 7.2859e+00],
#         [5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03,
#          5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03,
#          5.0792e-03, 5.0792e-03, 5.0792e-03, 5.0792e-03]], device='cuda:0')
# Regressed y: tensor([[ 0.8372,  0.8255,  0.8187,  0.8246,  0.8305,  0.8375,  0.8331,  0.8314,
#           0.8294,  0.8267,  0.8305,  0.8303,  0.8314,  0.8397,  0.8246,  0.8238],
#         [ 6.9768,  6.8157,  6.7542,  6.8749,  6.8412,  6.9442,  6.8917,  6.9129,
#           6.8723,  6.8571,  6.9311,  6.8411,  6.8824,  6.9325,  6.8080,  6.8716],
#         [-0.8013, -0.7565, -0.7474, -0.7771, -0.7782, -0.7807, -0.7860, -0.7899,
#          -0.7824, -0.7912, -0.7926, -0.7642, -0.7586, -0.7744, -0.7651, -0.8036]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_mu: tensor([[ 0.8372,  0.8255,  0.8187,  0.8246,  0.8305,  0.8375,  0.8331,  0.8314,
#           0.8294,  0.8267,  0.8305,  0.8303,  0.8314,  0.8397,  0.8246,  0.8238],
#         [ 6.9768,  6.8157,  6.7542,  6.8749,  6.8412,  6.9442,  6.8917,  6.9129,
#           6.8723,  6.8571,  6.9311,  6.8411,  6.8824,  6.9325,  6.8080,  6.8716],
#         [-0.8013, -0.7565, -0.7474, -0.7771, -0.7782, -0.7807, -0.7860, -0.7899,
#          -0.7824, -0.7912, -0.7926, -0.7642, -0.7586, -0.7744, -0.7651, -0.8036]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_std: tensor([[1.9194e-14, 2.5151e-14, 3.0559e-14, 2.4013e-14, 2.8145e-14, 1.9162e-14,
#          2.3619e-14, 2.3527e-14, 2.4859e-14, 3.0845e-14, 2.2212e-14, 2.7680e-14,
#          1.9492e-14, 1.8285e-14, 2.6984e-14, 3.3476e-14],
#         [6.9120e-12, 8.3619e-12, 9.7299e-12, 8.1071e-12, 9.3862e-12, 6.8488e-12,
#          8.1340e-12, 8.0987e-12, 8.4176e-12, 1.0150e-11, 7.7092e-12, 9.2235e-12,
#          6.8021e-12, 6.5917e-12, 8.8923e-12, 1.0903e-11],
#         [5.1445e-09, 5.7828e-09, 6.4577e-09, 5.7344e-09, 6.3830e-09, 5.0511e-09,
#          5.7557e-09, 5.7683e-09, 5.9032e-09, 6.8451e-09, 5.5738e-09, 6.2679e-09,
#          4.9575e-09, 4.8733e-09, 6.0816e-09, 7.2917e-09]], device='cuda:0',
#        grad_fn=<TBackward0>)
#
# Real y: tensor([[0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850,
#          0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850, 0.5850],
#         [0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451,
#          0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451, 0.5451],
#         [1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862,
#          1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862, 1.4862]],
#        device='cuda:0')
# Regressed y: tensor([[0.5524, 0.5454, 0.5440, 0.5521, 0.5484, 0.5512, 0.5481, 0.5490, 0.5475,
#          0.5471, 0.5563, 0.5394, 0.5563, 0.5455, 0.5443, 0.5447],
#         [1.2639, 1.1062, 1.1026, 1.1967, 1.2081, 1.1108, 1.1819, 1.2309, 1.2742,
#          1.0953, 1.2255, 1.1010, 1.2364, 1.1687, 1.1642, 1.1583],
#         [0.5954, 0.6517, 0.6541, 0.6608, 0.5985, 0.6269, 0.6159, 0.5815, 0.6184,
#          0.6229, 0.5919, 0.6334, 0.6142, 0.6139, 0.6266, 0.5822]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_mu: tensor([[0.5524, 0.5454, 0.5440, 0.5521, 0.5484, 0.5512, 0.5481, 0.5490, 0.5475,
#          0.5471, 0.5563, 0.5394, 0.5563, 0.5455, 0.5443, 0.5447],
#         [1.2639, 1.1062, 1.1026, 1.1967, 1.2081, 1.1108, 1.1819, 1.2309, 1.2742,
#          1.0953, 1.2255, 1.1010, 1.2364, 1.1687, 1.1642, 1.1583],
#         [0.5954, 0.6517, 0.6541, 0.6608, 0.5985, 0.6269, 0.6159, 0.5815, 0.6184,
#          0.6229, 0.5919, 0.6334, 0.6142, 0.6139, 0.6266, 0.5822]],
#        device='cuda:0', grad_fn=<TBackward0>)
# y_std: tensor([[3.9230e-11, 4.1656e-11, 4.5526e-11, 3.5154e-11, 5.1829e-11, 4.9509e-11,
#          4.2881e-11, 4.8927e-11, 3.5710e-11, 5.4023e-11, 4.9851e-11, 4.6427e-11,
#          3.7209e-11, 4.9972e-11, 4.6168e-11, 5.9095e-11],
#         [1.4736e-09, 1.5012e-09, 1.6177e-09, 1.3157e-09, 1.8504e-09, 1.7434e-09,
#          1.5645e-09, 1.7718e-09, 1.3603e-09, 1.8756e-09, 1.7933e-09, 1.6525e-09,
#          1.3963e-09, 1.7816e-09, 1.6613e-09, 2.0552e-09],
#         [7.3315e-08, 6.9996e-08, 7.4155e-08, 6.3897e-08, 8.6524e-08, 7.9335e-08,
#          7.4815e-08, 8.4674e-08, 6.8555e-08, 8.4080e-08, 8.4495e-08, 7.6286e-08,
#          6.8927e-08, 8.2745e-08, 7.7874e-08, 9.3612e-08]], device='cuda:0',
#        grad_fn=<TBackward0>)

# %%
stop!
# Out:
#   Cell In[14], line 1
#     stop!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Stacked Deep Generative Model
#
# The M1+M2 model also described in the same paper is an M1 model (VAE) with an M2 model stacked on top of it. That means that we train the a VAE end-to-end on the data given dataset, then we use the learned encoder as a feature extractor and feed the data transformed by the M1 encoder into the M2 model.
#
# We approach is somewhat similar to restricted boltzmann machines (RBMs) in the sense that we perform a layerwise training of the whole model by first training a level-1 feature extractor and stacking another model on top of this. The stacked model is therefore also more modular, but cannot be trained end-to-end, which is a downside.

# %%
from models import VariationalAutoencoder, StackedDeepGenerativeModel

features = VariationalAutoencoder([784, z_dim, h_dim])
model = StackedDeepGenerativeModel([784, y_dim, z_dim, h_dim], features)

# %% [markdown]
# Typically, you would want to load a pretrained feature extractor VAE instead.

# %%
features = torch.load("./your-pretrained-vae.pt")
# Out:
# C:\Users\jwang47\AppData\Local\Temp\ipykernel_15576\1198095296.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   features = torch.load("./your-pretrained-vae.pt")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 features = torch.load("./your-pretrained-vae.pt")
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File c:\Users\jwang47\AppData\Local\anaconda3\envs\pytorch20241014\Lib\site-packages\torch\serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './your-pretrained-vae.pt'

# %%
from torch.autograd import Variable

for epoch in range(10):
    model.train()
    total_loss, accuracy = (0, 0)
    for (x, y), (u, _) in zip(cycle(labelled), unlabelled):
        # Wrap in variables
        x, y, u = Variable(x), Variable(y), Variable(u)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            u = u.cuda(device=0)

        L = -elbo(x, y)
        U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        logits = model.classify(x)
        
        # Regular cross entropy
        classication_loss = torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

        J_alpha = L - alpha * classication_loss + U

        J_alpha.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.data[0]
        accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
        
    if epoch % 1 == 0:
        model.eval()
        m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        print("[Train]\t\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

        total_loss, accuracy = (0, 0)
        for x, y in validation:
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            U = -elbo(x)

            logits = model.classify(x)
            classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

            J_alpha = L + alpha * classication_loss + U

            total_loss += J_alpha.data[0]

            _, pred_idx = torch.max(logits, 1)
            _, lab_idx = torch.max(y, 1)
            accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

        m = len(validation)
        print("[Validation]\t J_a: {:.2f}, accuracy: {:.2f}".format(total_loss / m, accuracy / m))

# %% [markdown]
# ## Additional tips
#
# You can change the built-in classifier with your own, for example if you want a CNN as a classifier you can do the following.

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvolutionalClassifier(nn.Module):
    def __init__(self):
        super(ConvolutionalClassifier, self).__init__()        
        self.conv1 = nn.Conv2d(1, 64, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=3)
        self.pool = nn.MaxPool2d(kernel_size=4)

        size = int((28 - 3) + 1)//4
        size = int((size - 3) + 1)//4
                
        self.fc1 = nn.Linear(32*size**2, 50)
        self.fc2 = nn.Linear(50, 10)
        
    def forward(self, x):
        batch, *_ = x.size()
        x = x.view(-1, 1, 28, 28)
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(x.view(batch, -1))
        x = self.fc1(x)
        x = self.fc2(x)
        return F.softmax(x, dim=-1)

classifier = ConvolutionalClassifier()
model.classifier = classifier

# %%
model
# Out:
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=794, out_features=256)
#       (1): Linear(in_features=256, out_features=128)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32)
#       (log_var): Linear(in_features=128, out_features=32)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=42, out_features=128)
#       (1): Linear(in_features=128, out_features=256)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784)
#     (output_activation): Sigmoid()
#   )
#   (classifier): ConvolutionalClassifier(
#     (conv1): Conv2d (1, 64, kernel_size=(3, 3), stride=(1, 1))
#     (conv2): Conv2d (64, 32, kernel_size=(3, 3), stride=(1, 1))
#     (pool): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), dilation=(1, 1))
#     (fc1): Linear(in_features=32, out_features=50)
#     (fc2): Linear(in_features=50, out_features=10)
#   )
# )
